# %% [markdown]
# # RNN for captions

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load split data

# %%
train_df = pd.read_csv(
    "data/train_df.csv",
    parse_dates=["publish_timestamp"]  # converts datestime string into datetime object
)
test_df = pd.read_csv(
    "data/test_df.csv",
    parse_dates=["publish_timestamp"]
)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   user_id                   1471 non-null   int64
#  1   following                 1471 non-null   int64
#  2   publish_timestamp         1471 non-null   datetime64[ns]
#  3   has_location              1471 non-null   int64
#  4   is_carousel               1471 non-null   int64
#  5   num_images                1471 non-null   int64
#  6   is_sponsored              1471 non-null   int64
#  7   image_path                1471 non-null   object
#  8   caption                   1443 non-null   object
#  9   follower_following_ratio  1471 non-null   float64
#  10  hour                      1471 non-null   int64
#  11  day                       1471 non-null   object
#  12  is_weekend                1471 non-null   bool
#  13  caption_word_count        1471 non-null   int64
#  14  hashtags                  1471 non-null   object
#  15  num_hashtags              1471 non-null   int64
#  16  engagement_label          1471 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(10), object(4)
# memory usage: 185.4+ KB

# %% [markdown]
# # Set random seed

# %%
import random
import numpy as np
import torch

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if using multi-GPU

    # Ensure deterministic behavior (slower but reproducible)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
set_seed(42)

# %% [markdown]
# ### Fill any missing captions

# %%
train_df["caption"] = train_df["caption"].fillna("")
test_df["caption"]  = test_df["caption"].fillna("")

# %% [markdown]
# # LSTM

# %% [markdown]
# ### Tokenize captions & build vocabulary, using train_df

# %%
from collections import Counter
import torch
from torch.utils.data import Dataset, DataLoader
import re

# Simple tokenizer: split on spaces, remove non-alphanumeric chars
def tokenize(text):
    if not isinstance(text, str):
        return []
    # lowercase and keep only words (a-z, 0-9)
    text = text.lower()
    tokens = re.findall(r'\b\w+\b', text)
    return tokens

# Build vocab
all_tokens = []
for caption in train_df['caption']:
    all_tokens.extend(tokenize(caption))

# Count frequencies and build vocab
counter = Counter(all_tokens)
vocab = {"<PAD>": 0, "<UNK>": 1}  # reserve 0 for padding, 1 for unknown
for i, word in enumerate(counter.keys(), start=2):
    vocab[word] = i

vocab_size = len(vocab)
print(f"Vocab size: {vocab_size}")
# Out:
# Vocab size: 9991

# %% [markdown]
# ### Encode train_df captions to sequences and add padding

# %%
def encode_caption(caption, vocab, max_len):
    tokens = tokenize(caption)
    seq = [vocab.get(tok, vocab["<UNK>"]) for tok in tokens]
    # pad or truncate
    if len(seq) < max_len:
        seq += [vocab["<PAD>"]] * (max_len - len(seq))
    else:
        seq = seq[:max_len]
    return seq

# %% [markdown]
# ### Apply encoding to both train_df and test_df

# %%
# max_len = 64  # choose based on caption length distribution

# train_df["caption_seq"] = train_df["caption"].apply(
#     lambda x: encode_caption(x, vocab, max_len)
# )

# test_df["caption_seq"] = test_df["caption"].apply(
#     lambda x: encode_caption(x, vocab, max_len)
# )

# %%
# X_train = train_df["caption_seq"].tolist()
# y_train = train_df["engagement_label"].values

# X_test = test_df["caption_seq"].tolist()
# y_test = test_df["engagement_label"].values

# %% [markdown]
# ### Caption dataset

# %%
class CaptionDataset(Dataset):
    def __init__(self, sequences, labels):
        self.X = torch.tensor(sequences, dtype=torch.long)
        self.y = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# train_ds = CaptionDataset(X_train, y_train)
# test_ds  = CaptionDataset(X_test, y_test)

# %% [markdown]
# #### DataLoaders

# %%
# batch_size = 32
# train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
# test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Caption RNN model using PyTorch LSTM model

# %%
import torch.nn as nn

class CaptionRNN(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes=3, dropout=0.5):
        super().__init__()

        # Embedding layer for token-based text classification
        # Maps token id to dense vector
        # embed_dim affects how much semantic info each token carries
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)

        # Single-layer LSTM
        # each timestep is an embedding vector, which has size of embed_dim
        # returns: output, (hidden, cell)
        self.lstm = nn.LSTM(input_size=embed_dim, hidden_size=hidden_dim, batch_first=True)
        # Dropout after LSTM
        self.dropout = nn.Dropout(dropout)
        # Optional hidden layer
        self.fc_hidden = nn.Linear(hidden_dim, hidden_dim // 2)
        self.relu = nn.ReLU()
        self.fc_out = nn.Linear(hidden_dim // 2, num_classes)

    def forward(self, x):
        emb = self.embedding(x)                     # (batch_size, seq_len, embed_dim)
        _, (hidden, _) = self.lstm(emb)             # lstm output: output, (hidden, cell). output: (batch, seq_len, hidden_dim). hidden: (num_layers*num_directions, batch_size, hidden_dim).
        h = hidden.squeeze(0)                       # (batch_size, hidden_dim), can squeeze because num_layers*num_directions = 1
        h = self.dropout(h)                         # apply dropout
        h = self.fc_hidden(h)                       # optional hidden layer
        h = self.relu(h)                            # non-linearity
        h = self.dropout(h)                         # another dropout
        out = self.fc_out(h)                        # (batch_size, num_classes), output logits
        return out

# Hyperparameters
# embed_dim = 50
# hidden_dim = 64
# num_classes = 3
# dropout = 0.5
# learning_rate = 1e-3

# device = "cuda" if torch.cuda.is_available() else "cpu"
# model = CaptionRNN(vocab_size, embed_dim, hidden_dim, num_classes, dropout).to(device)

# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
# print(model)

# %% [markdown]
# ### Train and test loop

# %%
# training loop
def train_epoch(loader):
    # Put model in training mode
    model.train()

    # Initialize accumulator for total loss
    total_loss = 0

    # Loops over batches in training set
    for batch in loader:
        # Detect if batch is a dict (BERT-style) or tuple (LSTM/MLP/CNN)
        if isinstance(batch, dict):
            # BERT-style
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            optimizer.zero_grad()
            logits = model(input_ids=input_ids, attention_mask=attention_mask)

            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()

            # total_loss += loss.item()
            # correct += (logits.argmax(dim=1) == labels).sum().item()
            # total += labels.size(0)

        else:
            # Tuple-style: (X, y) for LSTM, MLP, CNN
            X, y = batch

            # Move x y to same device
            X, y = X.to(device), y.to(device)

            # Clear old gradients from previous batch
            optimizer.zero_grad()

            # Feeds batch into model, perform forward pass, output logits
            logits = model(X)
            # logits = model(input_ids=X["input_ids"], attention_mask=X["attention_mask"])


            # Compute loss for this batch
            loss = criterion(logits, y)

            # Performs backpropagation: computes gradients of the loss with respect to each model parameter.
            loss.backward()

            # Updates model parameters using those gradients
            optimizer.step()

        # Adds the numeric loss value (converted from a tensor with .item()) to the total loss accumulator.
        total_loss += loss.item()

    # Average loss = total loss / number of batches
    avg_loss = total_loss / len(loader)
    
    return avg_loss

# %%
def test_epoch(loader):
    # Set model to evaluation mode. Disables dropout, freezes batchnorm stats
    model.eval()

    # Initialize accumulator for total loss
    total_loss = 0

    with torch.no_grad(): # Disables gradient tracking inside this block.
    # This saves memory and time, since we don’t need gradients for validation.
    # It also ensures the model’s weights won’t accidentally be updated.
        for batch in loader:
            if isinstance(batch, dict):
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                logits = model(input_ids=input_ids, attention_mask=attention_mask)
                y = labels
                # total_loss += criterion(logits, labels).item()
            else:
                X, y = batch
                X, y = X.to(device), y.to(device)
    
                logits = model(X)
                # logits = model(input_ids=X["input_ids"], attention_mask=X["attention_mask"])


            total_loss += criterion(logits, y).item()

    # Compute average loss
    avg_loss = total_loss / len(loader)
    
    return avg_loss

# %%
from sklearn.metrics import confusion_matrix, f1_score

def evaluate_metrics(loader, model):
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in loader:
            if isinstance(batch, dict):
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                logits = model(input_ids=input_ids, attention_mask=attention_mask)
                y = labels
            else:
                X, y = batch
                X, y = X.to(device), y.to(device)

                logits = model(X)
                # logits = model(input_ids=X["input_ids"], attention_mask=X["attention_mask"])

            preds = logits.argmax(dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    # Accuracy
    correct = sum(p == y for p, y in zip(all_preds, all_labels))
    accuracy = correct / len(all_labels)

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)

    # Macro F1
    macro_f1 = f1_score(all_labels, all_preds, average="macro")

    return accuracy, cm, macro_f1

# %%
# class weights
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
import torch

classes = np.unique(y_train)   # e.g. [0, 1, 2]

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)

class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

print(class_weights)
# Out:
# tensor([1.0613, 0.9886, 0.9558], device='cuda:0')

# %% [markdown]
# ### Set fixed variables

# %%
# fixed variables

device = "cuda" if torch.cuda.is_available() else "cpu"

criterion = nn.CrossEntropyLoss(weight=class_weights)

y_train = train_df["engagement_label"].values
y_test = test_df["engagement_label"].values

# set seed for dataloader shuffling order to make it deterministic
g = torch.Generator()
g.manual_seed(42)

# %% [markdown]
# ### Tuning loop

# %%
import copy
import matplotlib.pyplot as plt

results = []
best_state = None
global_best_f1 = 0

patience = 5 # stop if no improvement after 5 epochs

# Initialize plot
plt.figure(figsize=(8,5))


for max_len in [32, 64, 128]:
    train_df["caption_seq"] = train_df["caption"].apply(
        lambda x: encode_caption(x, vocab, max_len)
    )

    test_df["caption_seq"] = test_df["caption"].apply(
        lambda x: encode_caption(x, vocab, max_len)
    )

    X_train = train_df["caption_seq"].tolist()
    X_test = test_df["caption_seq"].tolist()

    # Create dataset
    train_ds = CaptionDataset(X_train, y_train)
    test_ds  = CaptionDataset(X_test, y_test)

    # Load dataset
    batch_size = 32
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, generator=g)
    test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    for embed_dim in [50, 100]:
        for hidden_dim in [32, 64, 128]:
            for dropout in [0.3, 0.5, 0.6]:
                for learning_rate in [1e-3, 5e-4]:
                    print("\n=====\nNew tuning parameters: ")
                    print(f"hidden_dim: {hidden_dim}")
                    print(f"dropout: {dropout}")
                    print(f"learning_rate: {learning_rate}\n")
                    print(f"max_len: {max_len}\n")
                    print(f"embed_dim: {embed_dim}\n")

                    # Set parameters for model and optimizer
                    model = CaptionRNN(
                        vocab_size, 
                        embed_dim=embed_dim, 
                        hidden_dim=hidden_dim, 
                        dropout=dropout
                    ).to(device)

                    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

                    print(model)

                    # Re-initialize metrics before epochs
                    best_test_f1 = 0
                    best_row = None
                    no_improve_epochs = 0
                    train_macro_f1_list = []
                    test_macro_f1_list = []

                    for epoch in range(50):
                        train_loss = train_epoch(train_loader)
                        test_loss  = test_epoch(test_loader)

                        # Metrics
                        train_acc, train_cm, train_macro_f1 = evaluate_metrics(train_loader, model)
                        test_acc, test_cm, test_macro_f1 = evaluate_metrics(test_loader, model)

                        # Keep metrics for plotting
                        train_macro_f1_list.append(train_macro_f1)
                        test_macro_f1_list.append(test_macro_f1)

                        if test_macro_f1 > best_test_f1:
                            # Update best F1
                            best_test_f1 = test_macro_f1
                            # Save model metrics and parameters for plot/chart
                            best_row = {
                                "model": "LSTM",
                                "hidden_dim": hidden_dim,
                                "dropout": dropout,
                                "learning_rate": learning_rate,
                                "max_len": max_len,
                                "embed_dim": embed_dim,
                                "best_epoch": epoch + 1,
                                "train_macro_f1": train_macro_f1,
                                "train_acc": train_acc,
                                "train_cm": train_cm,
                                "test_macro_f1": test_macro_f1,
                                "test_acc": test_acc,
                                "test_cm": test_cm,

                                "train_f1_history": train_macro_f1_list.copy(),
                                "test_f1_history": test_macro_f1_list.copy(),
                            }
                            no_improve_epochs = 0  # reset patience counter
                            if test_macro_f1 > global_best_f1:
                                # Update global best F1
                                global_best_f1 = test_macro_f1
                                # Save model state for loading later using load_state_dict
                                best_state = copy.deepcopy(model.state_dict())
                        else:
                            no_improve_epochs += 1

                        print(f"\nEpoch {epoch+1}")
                        print(f"Train   | loss={train_loss:.4f}, acc={train_acc:.3f}, macro-F1={train_macro_f1:.3f}")
                        print(f"Test    | loss={test_loss:.4f}, acc={test_acc:.3f}, macro-F1={test_macro_f1:.3f}")

                        print("Train Confusion Matrix:")
                        print(train_cm)

                        print("Test Confusion Matrix:")
                        print(test_cm)

                        if no_improve_epochs >= patience:
                            print(f"Early stopping at epoch {epoch+1}")
                            break
                                
                    # Keep only the best epoch of the parameter configuration
                    results.append(best_row)
            
df_results = pd.DataFrame(results)
torch.save(best_state, "best_lstm_model.pt")
# Out:
# =====
# New tuning parameters:
# hidden_dim: 32
# dropout: 0.3
# learning_rate: 0.001
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 32, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc_hidden): Linear(in_features=32, out_features=16, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=16, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1004, acc=0.402, macro-F1=0.299
# Test    | loss=1.1068, acc=0.316, macro-F1=0.247
# Train Confusion Matrix:
# [[  3 174 285]
#  [  1 144 351]
#  [  1  68 444]]
# Test Confusion Matrix:
# [[ 0 61 86]
#  [ 1 31 82]
#  [ 0 27 88]]
#
# Epoch 2
# Train   | loss=1.0936, acc=0.431, macro-F1=0.379
# Test    | loss=1.0966, acc=0.362, macro-F1=0.326
# Train Confusion Matrix:
# [[ 62 181 219]
#  [ 31 164 301]
#  [ 23  82 408]]
# Test Confusion Matrix:
# [[14 66 67]
#  [ 4 39 71]
#  [ 7 25 83]]
#
# Epoch 3
# Train   | loss=1.0845, acc=0.470, macro-F1=0.442
# Test    | loss=1.0830, acc=0.396, macro-F1=0.380
# Train Confusion Matrix:
# [[172  87 203]
#  [ 87 118 291]
#  [ 47  64 402]]
# Test Confusion Matrix:
# [[42 46 59]
#  [17 29 68]
#  [18 19 78]]
#
# Epoch 4
# Train   | loss=1.0607, acc=0.482, macro-F1=0.427
# Test    | loss=1.0656, acc=0.447, macro-F1=0.374
# Train Confusion Matrix:
# [[274  26 162]
#  [204  48 244]
#  [ 94  32 387]]
# Test Confusion Matrix:
# [[95  9 43]
#  [56  5 53]
#  [42  5 68]]
#
# Epoch 5
# Train   | loss=1.0335, acc=0.525, macro-F1=0.472
# Test    | loss=1.0722, acc=0.444, macro-F1=0.382
# Train Confusion Matrix:
# [[292  32 138]
#  [194  63 239]
#  [ 66  30 417]]
# Test Confusion Matrix:
# [[98 16 33]
#  [59  8 47]
#  [45  9 61]]
#
# Epoch 6
# Train   | loss=0.9989, acc=0.553, macro-F1=0.500
# Test    | loss=1.0834, acc=0.439, macro-F1=0.373
# Train Confusion Matrix:
# [[277  30 155]
#  [147  75 274]
#  [ 37  15 461]]
# Test Confusion Matrix:
# [[89 13 45]
#  [57  6 51]
#  [40  5 70]]
#
# Epoch 7
# Train   | loss=0.9730, acc=0.549, macro-F1=0.480
# Test    | loss=1.1053, acc=0.460, macro-F1=0.390
# Train Confusion Matrix:
# [[298   8 156]
#  [180  48 268]
#  [ 37  14 462]]
# Test Confusion Matrix:
# [[94  5 48]
#  [55  7 52]
#  [39  4 72]]
#
# Epoch 8
# Train   | loss=0.9219, acc=0.613, macro-F1=0.562
# Test    | loss=1.2449, acc=0.428, macro-F1=0.356
# Train Confusion Matrix:
# [[353  14  95]
#  [182  89 225]
#  [ 25  29 459]]
# Test Confusion Matrix:
# [[107   9  31]
#  [ 67   7  40]
#  [ 60   8  47]]
#
# Epoch 9
# Train   | loss=0.8817, acc=0.650, macro-F1=0.625
# Test    | loss=1.1456, acc=0.436, macro-F1=0.394
# Train Confusion Matrix:
# [[307  39 116]
#  [ 68 152 276]
#  [  5  11 497]]
# Test Confusion Matrix:
# [[77 25 45]
#  [48 13 53]
#  [33  8 74]]
#
# Epoch 10
# Train   | loss=0.8436, acc=0.644, macro-F1=0.621
# Test    | loss=1.1618, acc=0.441, macro-F1=0.408
# Train Confusion Matrix:
# [[297  24 141]
#  [ 50 150 296]
#  [  2  10 501]]
# Test Confusion Matrix:
# [[70 21 56]
#  [35 18 61]
#  [28  9 78]]
#
# Epoch 11
# Train   | loss=0.8146, acc=0.696, macro-F1=0.668
# Test    | loss=1.4617, acc=0.423, macro-F1=0.357
# Train Confusion Matrix:
# [[374  11  77]
#  [107 160 229]
#  [  6  17 490]]
# Test Confusion Matrix:
# [[99 12 36]
#  [64  7 43]
#  [55  7 53]]
#
# Epoch 12
# Train   | loss=0.7812, acc=0.688, macro-F1=0.666
# Test    | loss=1.2878, acc=0.431, macro-F1=0.377
# Train Confusion Matrix:
# [[344  20  98]
#  [ 68 169 259]
#  [  2  12 499]]
# Test Confusion Matrix:
# [[85 15 47]
#  [55  9 50]
#  [38  9 68]]
#
# Epoch 13
# Train   | loss=0.7482, acc=0.743, macro-F1=0.731
# Test    | loss=1.4393, acc=0.420, macro-F1=0.384
# Train Confusion Matrix:
# [[381  16  65]
#  [ 54 219 223]
#  [  3  17 493]]
# Test Confusion Matrix:
# [[85 24 38]
#  [55 15 44]
#  [39 18 58]]
#
# Epoch 14
# Train   | loss=0.6953, acc=0.761, macro-F1=0.753
# Test    | loss=1.3935, acc=0.449, macro-F1=0.429
# Train Confusion Matrix:
# [[381  18  63]
#  [ 35 239 222]
#  [  2  12 499]]
# Test Confusion Matrix:
# [[81 24 42]
#  [41 26 47]
#  [28 25 62]]
#
# Epoch 15
# Train   | loss=0.6677, acc=0.687, macro-F1=0.678
# Test    | loss=1.2887, acc=0.444, macro-F1=0.431
# Train Confusion Matrix:
# [[302  63  97]
#  [  6 203 287]
#  [  0   7 506]]
# Test Confusion Matrix:
# [[58 40 49]
#  [23 32 59]
#  [23 15 77]]
#
# Epoch 16
# Train   | loss=0.6790, acc=0.752, macro-F1=0.738
# Test    | loss=1.8375, acc=0.418, macro-F1=0.367
# Train Confusion Matrix:
# [[401   2  59]
#  [ 75 216 205]
#  [  2  22 489]]
# Test Confusion Matrix:
# [[97 18 32]
#  [60 13 41]
#  [63  5 47]]
#
# Epoch 17
# Train   | loss=0.6201, acc=0.789, macro-F1=0.786
# Test    | loss=1.6616, acc=0.412, macro-F1=0.395
# Train Confusion Matrix:
# [[393  11  58]
#  [ 18 264 214]
#  [  1   9 503]]
# Test Confusion Matrix:
# [[77 33 37]
#  [45 26 43]
#  [36 27 52]]
#
# Epoch 18
# Train   | loss=0.5989, acc=0.791, macro-F1=0.786
# Test    | loss=1.9708, acc=0.407, macro-F1=0.379
# Train Confusion Matrix:
# [[401   3  58]
#  [ 29 257 210]
#  [  1   6 506]]
# Test Confusion Matrix:
# [[85 31 31]
#  [52 20 42]
#  [50 17 48]]
#
# Epoch 19
# Train   | loss=0.5783, acc=0.797, macro-F1=0.797
# Test    | loss=1.7463, acc=0.415, macro-F1=0.401
# Train Confusion Matrix:
# [[386  18  58]
#  [  6 277 213]
#  [  1   2 510]]
# Test Confusion Matrix:
# [[77 36 34]
#  [41 28 45]
#  [32 32 51]]
#
# Epoch 20
# Train   | loss=0.5452, acc=0.800, macro-F1=0.799
# Test    | loss=1.8063, acc=0.441, macro-F1=0.422
# Train Confusion Matrix:
# [[397   8  57]
#  [  6 269 221]
#  [  1   1 511]]
# Test Confusion Matrix:
# [[84 25 38]
#  [42 28 44]
#  [36 25 54]]
# Early stopping at epoch 20
#
# =====
# New tuning parameters:
# hidden_dim: 32
# dropout: 0.3
# learning_rate: 0.0005
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 32, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc_hidden): Linear(in_features=32, out_features=16, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=16, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1111, acc=0.337, macro-F1=0.169
# Test    | loss=1.1075, acc=0.303, macro-F1=0.155
# Train Confusion Matrix:
# [[  1 461   0]
#  [  2 494   0]
#  [  0 513   0]]
# Test Confusion Matrix:
# [[  0 147   0]
#  [  0 114   0]
#  [  0 115   0]]
#
# Epoch 2
# Train   | loss=1.1016, acc=0.341, macro-F1=0.185
# Test    | loss=1.0999, acc=0.316, macro-F1=0.179
# Train Confusion Matrix:
# [[ 13 449   0]
#  [  8 488   0]
#  [  4 509   0]]
# Test Confusion Matrix:
# [[  5 142   0]
#  [  0 114   0]
#  [  4 111   0]]
#
# Epoch 3
# Train   | loss=1.0921, acc=0.366, macro-F1=0.252
# Test    | loss=1.0938, acc=0.338, macro-F1=0.231
# Train Confusion Matrix:
# [[ 73 388   1]
#  [ 31 464   1]
#  [ 28 484   1]]
# Test Confusion Matrix:
# [[ 18 128   1]
#  [  6 108   0]
#  [  9 105   1]]
#
# Epoch 4
# Train   | loss=1.0863, acc=0.459, macro-F1=0.431
# Test    | loss=1.0908, acc=0.394, macro-F1=0.369
# Train Confusion Matrix:
# [[116 152 194]
#  [ 42 172 282]
#  [ 39  87 387]]
# Test Confusion Matrix:
# [[31 51 65]
#  [12 31 71]
#  [12 17 86]]
#
# Epoch 5
# Train   | loss=1.0763, acc=0.477, macro-F1=0.450
# Test    | loss=1.0864, acc=0.404, macro-F1=0.374
# Train Confusion Matrix:
# [[153 100 209]
#  [ 57 143 296]
#  [ 54  54 405]]
# Test Confusion Matrix:
# [[39 37 71]
#  [16 23 75]
#  [17  8 90]]
#
# Epoch 6
# Train   | loss=1.0688, acc=0.486, macro-F1=0.463
# Test    | loss=1.0790, acc=0.436, macro-F1=0.407
# Train Confusion Matrix:
# [[195  70 197]
#  [ 87 126 283]
#  [ 67  52 394]]
# Test Confusion Matrix:
# [[56 26 65]
#  [20 21 73]
#  [23  5 87]]
#
# Epoch 7
# Train   | loss=1.0613, acc=0.504, macro-F1=0.487
# Test    | loss=1.0728, acc=0.444, macro-F1=0.420
# Train Confusion Matrix:
# [[221  58 183]
#  [105 141 250]
#  [ 76  57 380]]
# Test Confusion Matrix:
# [[59 25 63]
#  [22 24 68]
#  [22  9 84]]
#
# Epoch 8
# Train   | loss=1.0409, acc=0.501, macro-F1=0.478
# Test    | loss=1.0672, acc=0.428, macro-F1=0.388
# Train Confusion Matrix:
# [[255  62 145]
#  [158 116 222]
#  [ 98  49 366]]
# Test Confusion Matrix:
# [[67 20 60]
#  [34 14 66]
#  [28  7 80]]
#
# Epoch 9
# Train   | loss=1.0263, acc=0.544, macro-F1=0.536
# Test    | loss=1.0594, acc=0.455, macro-F1=0.443
# Train Confusion Matrix:
# [[311  78  73]
#  [180 177 139]
#  [106  95 312]]
# Test Confusion Matrix:
# [[73 36 38]
#  [38 32 44]
#  [28 21 66]]
#
# Epoch 10
# Train   | loss=0.9920, acc=0.581, macro-F1=0.574
# Test    | loss=1.0646, acc=0.441, macro-F1=0.434
# Train Confusion Matrix:
# [[271 115  76]
#  [126 215 155]
#  [ 63  82 368]]
# Test Confusion Matrix:
# [[58 38 51]
#  [28 37 49]
#  [21 23 71]]
#
# Epoch 11
# Train   | loss=0.9516, acc=0.629, macro-F1=0.621
# Test    | loss=1.0664, acc=0.463, macro-F1=0.456
# Train Confusion Matrix:
# [[305  88  69]
#  [147 227 122]
#  [ 65  55 393]]
# Test Confusion Matrix:
# [[64 34 49]
#  [31 39 44]
#  [24 20 71]]
#
# Epoch 12
# Train   | loss=0.9262, acc=0.622, macro-F1=0.607
# Test    | loss=1.0855, acc=0.444, macro-F1=0.433
# Train Confusion Matrix:
# [[336  66  60]
#  [207 179 110]
#  [ 67  46 400]]
# Test Confusion Matrix:
# [[69 35 43]
#  [42 32 40]
#  [28 21 66]]
#
# Epoch 13
# Train   | loss=0.8934, acc=0.661, macro-F1=0.656
# Test    | loss=1.0979, acc=0.436, macro-F1=0.436
# Train Confusion Matrix:
# [[263 145  54]
#  [ 97 306  93]
#  [ 49  61 403]]
# Test Confusion Matrix:
# [[53 57 37]
#  [26 49 39]
#  [21 32 62]]
#
# Epoch 14
# Train   | loss=0.8775, acc=0.656, macro-F1=0.653
# Test    | loss=1.1350, acc=0.410, macro-F1=0.411
# Train Confusion Matrix:
# [[237 184  41]
#  [ 73 356  67]
#  [ 44  97 372]]
# Test Confusion Matrix:
# [[50 71 26]
#  [24 57 33]
#  [21 47 47]]
#
# Epoch 15
# Train   | loss=0.8369, acc=0.684, macro-F1=0.678
# Test    | loss=1.1063, acc=0.444, macro-F1=0.438
# Train Confusion Matrix:
# [[267 138  57]
#  [ 81 311 104]
#  [ 36  49 428]]
# Test Confusion Matrix:
# [[52 53 42]
#  [26 41 47]
#  [19 22 74]]
#
# Epoch 16
# Train   | loss=0.8066, acc=0.710, macro-F1=0.705
# Test    | loss=1.1393, acc=0.428, macro-F1=0.428
# Train Confusion Matrix:
# [[279 136  47]
#  [ 83 331  82]
#  [ 31  48 434]]
# Test Confusion Matrix:
# [[52 59 36]
#  [24 47 43]
#  [20 33 62]]
# Early stopping at epoch 16
#
# =====
# New tuning parameters:
# hidden_dim: 32
# dropout: 0.5
# learning_rate: 0.001
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 32, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc_hidden): Linear(in_features=32, out_features=16, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=16, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1014, acc=0.359, macro-F1=0.211
# Test    | loss=1.1092, acc=0.322, macro-F1=0.210
# Train Confusion Matrix:
# [[  1  29 432]
#  [  1  31 464]
#  [  0  17 496]]
# Test Confusion Matrix:
# [[  0  22 125]
#  [  0  11 103]
#  [  0   5 110]]
#
# Epoch 2
# Train   | loss=1.0960, acc=0.379, macro-F1=0.252
# Test    | loss=1.1067, acc=0.324, macro-F1=0.236
# Train Confusion Matrix:
# [[  4  68 390]
#  [  6  67 423]
#  [  1  26 486]]
# Test Confusion Matrix:
# [[  1  38 108]
#  [  1  19  94]
#  [  1  12 102]]
#
# Epoch 3
# Train   | loss=1.0913, acc=0.453, macro-F1=0.407
# Test    | loss=1.1005, acc=0.348, macro-F1=0.300
# Train Confusion Matrix:
# [[129  65 268]
#  [ 43  95 358]
#  [ 36  34 443]]
# Test Confusion Matrix:
# [[16 43 88]
#  [ 6 23 85]
#  [ 9 14 92]]
#
# Epoch 4
# Train   | loss=1.0859, acc=0.492, macro-F1=0.459
# Test    | loss=1.0943, acc=0.362, macro-F1=0.330
# Train Confusion Matrix:
# [[196  41 225]
#  [ 78 105 313]
#  [ 64  26 423]]
# Test Confusion Matrix:
# [[29 43 75]
#  [12 22 80]
#  [15 15 85]]
#
# Epoch 5
# Train   | loss=1.0776, acc=0.487, macro-F1=0.440
# Test    | loss=1.0845, acc=0.394, macro-F1=0.355
# Train Confusion Matrix:
# [[239  21 202]
#  [132  68 296]
#  [ 88  16 409]]
# Test Confusion Matrix:
# [[55 27 65]
#  [26 12 76]
#  [24 10 81]]
#
# Epoch 6
# Train   | loss=1.0564, acc=0.458, macro-F1=0.388
# Test    | loss=1.0653, acc=0.465, macro-F1=0.374
# Train Confusion Matrix:
# [[382   4  76]
#  [297  24 175]
#  [234  12 267]]
# Test Confusion Matrix:
# [[123   7  17]
#  [ 70   6  38]
#  [ 68   1  46]]
#
# Epoch 7
# Train   | loss=1.0330, acc=0.516, macro-F1=0.455
# Test    | loss=1.0575, acc=0.463, macro-F1=0.381
# Train Confusion Matrix:
# [[347  14 101]
#  [247  46 203]
#  [122  25 366]]
# Test Confusion Matrix:
# [[106  12  29]
#  [ 64   4  46]
#  [ 50   1  64]]
#
# Epoch 8
# Train   | loss=0.9914, acc=0.579, macro-F1=0.517
# Test    | loss=1.0713, acc=0.452, macro-F1=0.381
# Train Confusion Matrix:
# [[369   4  89]
#  [222  63 211]
#  [ 75  18 420]]
# Test Confusion Matrix:
# [[101  15  31]
#  [ 60   6  48]
#  [ 49   3  63]]
#
# Epoch 9
# Train   | loss=0.9637, acc=0.595, macro-F1=0.550
# Test    | loss=1.0802, acc=0.426, macro-F1=0.368
# Train Confusion Matrix:
# [[306  17 139]
#  [116  93 287]
#  [ 14  23 476]]
# Test Confusion Matrix:
# [[73 21 53]
#  [40  7 67]
#  [32  3 80]]
#
# Epoch 10
# Train   | loss=0.9167, acc=0.631, macro-F1=0.578
# Test    | loss=1.0926, acc=0.455, macro-F1=0.402
# Train Confusion Matrix:
# [[357   7  98]
#  [129  86 281]
#  [  9  19 485]]
# Test Confusion Matrix:
# [[90 20 37]
#  [44 11 59]
#  [39  6 70]]
#
# Epoch 11
# Train   | loss=0.8783, acc=0.649, macro-F1=0.602
# Test    | loss=1.2050, acc=0.471, macro-F1=0.393
# Train Confusion Matrix:
# [[370   4  88]
#  [131 102 263]
#  [ 11  19 483]]
# Test Confusion Matrix:
# [[108  10  29]
#  [ 62   6  46]
#  [ 47   5  63]]
#
# Epoch 12
# Train   | loss=0.8364, acc=0.674, macro-F1=0.633
# Test    | loss=1.1907, acc=0.457, macro-F1=0.423
# Train Confusion Matrix:
# [[377   3  82]
#  [116 122 258]
#  [  6  15 492]]
# Test Confusion Matrix:
# [[87 23 37]
#  [47 19 48]
#  [37 12 66]]
#
# Epoch 13
# Train   | loss=0.8415, acc=0.663, macro-F1=0.629
# Test    | loss=1.2118, acc=0.388, macro-F1=0.358
# Train Confusion Matrix:
# [[353  17  92]
#  [ 36 114 346]
#  [  3   2 508]]
# Test Confusion Matrix:
# [[45 32 70]
#  [24 18 72]
#  [20 12 83]]
#
# Epoch 14
# Train   | loss=0.8158, acc=0.685, macro-F1=0.652
# Test    | loss=1.1800, acc=0.476, macro-F1=0.438
# Train Confusion Matrix:
# [[390   6  66]
#  [123 143 230]
#  [  9  29 475]]
# Test Confusion Matrix:
# [[89 28 30]
#  [43 18 53]
#  [35  8 72]]
#
# Epoch 15
# Train   | loss=0.7697, acc=0.714, macro-F1=0.688
# Test    | loss=1.2528, acc=0.457, macro-F1=0.425
# Train Confusion Matrix:
# [[393   3  66]
#  [ 74 160 262]
#  [  1  14 498]]
# Test Confusion Matrix:
# [[82 32 33]
#  [39 18 57]
#  [30 13 72]]
#
# Epoch 16
# Train   | loss=0.7360, acc=0.735, macro-F1=0.721
# Test    | loss=1.2789, acc=0.471, macro-F1=0.454
# Train Confusion Matrix:
# [[393   4  65]
#  [ 46 196 254]
#  [  0  21 492]]
# Test Confusion Matrix:
# [[75 39 33]
#  [28 29 57]
#  [25 17 73]]
#
# Epoch 17
# Train   | loss=0.7024, acc=0.776, macro-F1=0.772
# Test    | loss=1.2963, acc=0.441, macro-F1=0.437
# Train Confusion Matrix:
# [[393   8  61]
#  [ 27 258 211]
#  [  0  23 490]]
# Test Confusion Matrix:
# [[53 59 35]
#  [26 40 48]
#  [20 22 73]]
#
# Epoch 18
# Train   | loss=0.6847, acc=0.789, macro-F1=0.785
# Test    | loss=1.3636, acc=0.434, macro-F1=0.431
# Train Confusion Matrix:
# [[398   7  57]
#  [ 29 263 204]
#  [  0  13 500]]
# Test Confusion Matrix:
# [[54 60 33]
#  [26 42 46]
#  [22 26 67]]
#
# Epoch 19
# Train   | loss=0.6438, acc=0.842, macro-F1=0.844
# Test    | loss=1.3673, acc=0.455, macro-F1=0.457
# Train Confusion Matrix:
# [[398  11  53]
#  [  8 346 142]
#  [  0  19 494]]
# Test Confusion Matrix:
# [[51 73 23]
#  [20 63 31]
#  [18 40 57]]
#
# Epoch 20
# Train   | loss=0.5764, acc=0.856, macro-F1=0.858
# Test    | loss=1.5734, acc=0.455, macro-F1=0.457
# Train Confusion Matrix:
# [[390  19  53]
#  [  9 368 119]
#  [  0  12 501]]
# Test Confusion Matrix:
# [[57 68 22]
#  [25 61 28]
#  [19 43 53]]
#
# Epoch 21
# Train   | loss=0.5716, acc=0.867, macro-F1=0.870
# Test    | loss=1.7221, acc=0.426, macro-F1=0.423
# Train Confusion Matrix:
# [[399  26  37]
#  [  7 408  81]
#  [  0  44 469]]
# Test Confusion Matrix:
# [[59 73 15]
#  [29 64 21]
#  [22 56 37]]
#
# Epoch 22
# Train   | loss=0.5223, acc=0.884, macro-F1=0.886
# Test    | loss=1.8716, acc=0.415, macro-F1=0.411
# Train Confusion Matrix:
# [[402  22  38]
#  [  7 412  77]
#  [  0  26 487]]
# Test Confusion Matrix:
# [[57 77 13]
#  [28 65 21]
#  [23 58 34]]
#
# Epoch 23
# Train   | loss=0.5122, acc=0.886, macro-F1=0.888
# Test    | loss=2.0013, acc=0.460, macro-F1=0.459
# Train Confusion Matrix:
# [[400  11  51]
#  [  9 396  91]
#  [  0   5 508]]
# Test Confusion Matrix:
# [[71 52 24]
#  [37 49 28]
#  [27 35 53]]
#
# Epoch 24
# Train   | loss=0.5101, acc=0.893, macro-F1=0.894
# Test    | loss=1.8900, acc=0.449, macro-F1=0.450
# Train Confusion Matrix:
# [[400  13  49]
#  [  6 409  81]
#  [  0   9 504]]
# Test Confusion Matrix:
# [[47 79 21]
#  [17 69 28]
#  [18 44 53]]
#
# Epoch 25
# Train   | loss=0.4750, acc=0.891, macro-F1=0.894
# Test    | loss=1.8251, acc=0.447, macro-F1=0.445
# Train Confusion Matrix:
# [[404   7  51]
#  [  3 398  95]
#  [  0   4 509]]
# Test Confusion Matrix:
# [[41 77 29]
#  [16 63 35]
#  [15 36 64]]
#
# Epoch 26
# Train   | loss=0.4801, acc=0.900, macro-F1=0.902
# Test    | loss=1.8826, acc=0.457, macro-F1=0.459
# Train Confusion Matrix:
# [[403   9  50]
#  [  3 412  81]
#  [  0   4 509]]
# Test Confusion Matrix:
# [[55 69 23]
#  [22 65 27]
#  [18 45 52]]
#
# Epoch 27
# Train   | loss=0.4630, acc=0.895, macro-F1=0.896
# Test    | loss=1.9504, acc=0.420, macro-F1=0.417
# Train Confusion Matrix:
# [[392  28  42]
#  [  3 424  69]
#  [  0  12 501]]
# Test Confusion Matrix:
# [[44 87 16]
#  [18 74 22]
#  [14 61 40]]
#
# Epoch 28
# Train   | loss=0.5655, acc=0.855, macro-F1=0.856
# Test    | loss=1.7393, acc=0.423, macro-F1=0.422
# Train Confusion Matrix:
# [[389  21  52]
#  [  3 356 137]
#  [  0   1 512]]
# Test Confusion Matrix:
# [[43 69 35]
#  [17 55 42]
#  [15 39 61]]
#
# Epoch 29
# Train   | loss=0.5204, acc=0.876, macro-F1=0.875
# Test    | loss=1.7234, acc=0.404, macro-F1=0.397
# Train Confusion Matrix:
# [[364  52  46]
#  [  3 416  77]
#  [  0   5 508]]
# Test Confusion Matrix:
# [[36 91 20]
#  [15 75 24]
#  [10 64 41]]
#
# Epoch 30
# Train   | loss=0.4700, acc=0.902, macro-F1=0.903
# Test    | loss=2.0812, acc=0.418, macro-F1=0.417
# Train Confusion Matrix:
# [[400  18  44]
#  [  4 417  75]
#  [  0   3 510]]
# Test Confusion Matrix:
# [[53 75 19]
#  [25 64 25]
#  [16 59 40]]
#
# Epoch 31
# Train   | loss=0.4511, acc=0.890, macro-F1=0.889
# Test    | loss=1.9127, acc=0.383, macro-F1=0.357
# Train Confusion Matrix:
# [[371  49  42]
#  [  2 430  64]
#  [  0   5 508]]
# Test Confusion Matrix:
# [[ 23 105  19]
#  [  7  87  20]
#  [  7  74  34]]
# Early stopping at epoch 31
#
# =====
# New tuning parameters:
# hidden_dim: 32
# dropout: 0.5
# learning_rate: 0.0005
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 32, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc_hidden): Linear(in_features=32, out_features=16, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=16, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1030, acc=0.350, macro-F1=0.176
# Test    | loss=1.1039, acc=0.303, macro-F1=0.155
# Train Confusion Matrix:
# [[  2   0 460]
#  [  1   0 495]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  0   0 147]
#  [  0   0 114]
#  [  1   0 114]]
#
# Epoch 2
# Train   | loss=1.0992, acc=0.355, macro-F1=0.189
# Test    | loss=1.1017, acc=0.306, macro-F1=0.160
# Train Confusion Matrix:
# [[ 11   0 451]
#  [  6   0 490]
#  [  2   0 511]]
# Test Confusion Matrix:
# [[  1   0 146]
#  [  1   0 113]
#  [  1   0 114]]
#
# Epoch 3
# Train   | loss=1.0966, acc=0.382, macro-F1=0.248
# Test    | loss=1.0995, acc=0.330, macro-F1=0.218
# Train Confusion Matrix:
# [[ 56   0 406]
#  [ 24   2 470]
#  [  9   0 504]]
# Test Confusion Matrix:
# [[ 11   3 133]
#  [  4   3 107]
#  [  5   0 110]]
#
# Epoch 4
# Train   | loss=1.0934, acc=0.401, macro-F1=0.287
# Test    | loss=1.0976, acc=0.346, macro-F1=0.257
# Train Confusion Matrix:
# [[ 94   2 366]
#  [ 44   4 448]
#  [ 20   1 492]]
# Test Confusion Matrix:
# [[ 24   5 118]
#  [ 10   3 101]
#  [ 10   2 103]]
#
# Epoch 5
# Train   | loss=1.0907, acc=0.433, macro-F1=0.345
# Test    | loss=1.0942, acc=0.364, macro-F1=0.298
# Train Confusion Matrix:
# [[147   3 312]
#  [ 64  18 414]
#  [ 37   4 472]]
# Test Confusion Matrix:
# [[ 36   8 103]
#  [ 16   6  92]
#  [ 17   3  95]]
#
# Epoch 6
# Train   | loss=1.0823, acc=0.455, macro-F1=0.387
# Test    | loss=1.0901, acc=0.386, macro-F1=0.327
# Train Confusion Matrix:
# [[187   9 266]
#  [ 80  36 380]
#  [ 60   6 447]]
# Test Confusion Matrix:
# [[48 10 89]
#  [22  7 85]
#  [21  4 90]]
#
# Epoch 7
# Train   | loss=1.0773, acc=0.463, macro-F1=0.396
# Test    | loss=1.0851, acc=0.396, macro-F1=0.329
# Train Confusion Matrix:
# [[213  11 238]
#  [111  35 350]
#  [ 76   4 433]]
# Test Confusion Matrix:
# [[58  7 82]
#  [29  4 81]
#  [24  4 87]]
#
# Epoch 8
# Train   | loss=1.0707, acc=0.477, macro-F1=0.412
# Test    | loss=1.0776, acc=0.431, macro-F1=0.355
# Train Confusion Matrix:
# [[242  14 206]
#  [137  38 321]
#  [ 87   4 422]]
# Test Confusion Matrix:
# [[77  5 65]
#  [36  3 75]
#  [30  3 82]]
#
# Epoch 9
# Train   | loss=1.0546, acc=0.481, macro-F1=0.419
# Test    | loss=1.0626, acc=0.441, macro-F1=0.358
# Train Confusion Matrix:
# [[286   9 167]
#  [188  39 269]
#  [121  10 382]]
# Test Confusion Matrix:
# [[91  6 50]
#  [55  2 57]
#  [39  3 73]]
#
# Epoch 10
# Train   | loss=1.0478, acc=0.499, macro-F1=0.446
# Test    | loss=1.0587, acc=0.447, macro-F1=0.379
# Train Confusion Matrix:
# [[287  19 156]
#  [178  55 263]
#  [ 96  25 392]]
# Test Confusion Matrix:
# [[88  8 51]
#  [53  6 55]
#  [35  6 74]]
#
# Epoch 11
# Train   | loss=1.0347, acc=0.520, macro-F1=0.468
# Test    | loss=1.0510, acc=0.471, macro-F1=0.413
# Train Confusion Matrix:
# [[310  17 135]
#  [193  61 242]
#  [ 94  25 394]]
# Test Confusion Matrix:
# [[98 16 33]
#  [53 11 50]
#  [42  5 68]]
#
# Epoch 12
# Train   | loss=1.0127, acc=0.557, macro-F1=0.507
# Test    | loss=1.0512, acc=0.460, macro-F1=0.405
# Train Confusion Matrix:
# [[329  16 117]
#  [174  74 248]
#  [ 72  25 416]]
# Test Confusion Matrix:
# [[94 19 34]
#  [50 10 54]
#  [35 11 69]]
#
# Epoch 13
# Train   | loss=0.9766, acc=0.567, macro-F1=0.531
# Test    | loss=1.0623, acc=0.457, macro-F1=0.412
# Train Confusion Matrix:
# [[281  26 155]
#  [ 94 102 300]
#  [ 35  27 451]]
# Test Confusion Matrix:
# [[70 21 56]
#  [36 14 64]
#  [21  6 88]]
#
# Epoch 14
# Train   | loss=0.9560, acc=0.613, macro-F1=0.574
# Test    | loss=1.0562, acc=0.479, macro-F1=0.421
# Train Confusion Matrix:
# [[348   9 105]
#  [134 109 253]
#  [ 40  29 444]]
# Test Confusion Matrix:
# [[94 13 40]
#  [47 11 56]
#  [31  9 75]]
#
# Epoch 15
# Train   | loss=0.9108, acc=0.630, macro-F1=0.592
# Test    | loss=1.0645, acc=0.460, macro-F1=0.412
# Train Confusion Matrix:
# [[331  15 116]
#  [ 87 111 298]
#  [ 16  12 485]]
# Test Confusion Matrix:
# [[77 16 54]
#  [38 13 63]
#  [25  7 83]]
#
# Epoch 16
# Train   | loss=0.8941, acc=0.619, macro-F1=0.576
# Test    | loss=1.1066, acc=0.481, macro-F1=0.426
# Train Confusion Matrix:
# [[349  13 100]
#  [125 101 270]
#  [ 23  30 460]]
# Test Confusion Matrix:
# [[90 14 43]
#  [44 12 58]
#  [32  4 79]]
#
# Epoch 17
# Train   | loss=0.8633, acc=0.665, macro-F1=0.632
# Test    | loss=1.0958, acc=0.463, macro-F1=0.426
# Train Confusion Matrix:
# [[353  16  93]
#  [ 63 127 306]
#  [  5  10 498]]
# Test Confusion Matrix:
# [[71 21 55]
#  [30 18 66]
#  [23  7 85]]
#
# Epoch 18
# Train   | loss=0.8241, acc=0.675, macro-F1=0.644
# Test    | loss=1.1137, acc=0.484, macro-F1=0.449
# Train Confusion Matrix:
# [[360  12  90]
#  [ 74 137 285]
#  [  5  12 496]]
# Test Confusion Matrix:
# [[81 17 49]
#  [33 20 61]
#  [25  9 81]]
#
# Epoch 19
# Train   | loss=0.8282, acc=0.680, macro-F1=0.648
# Test    | loss=1.1655, acc=0.465, macro-F1=0.425
# Train Confusion Matrix:
# [[379   5  78]
#  [ 79 133 284]
#  [  8  16 489]]
# Test Confusion Matrix:
# [[75 24 48]
#  [32 16 66]
#  [24  7 84]]
#
# Epoch 20
# Train   | loss=0.7978, acc=0.697, macro-F1=0.674
# Test    | loss=1.1570, acc=0.481, macro-F1=0.444
# Train Confusion Matrix:
# [[378   6  78]
#  [ 57 157 282]
#  [  4  18 491]]
# Test Confusion Matrix:
# [[79 18 50]
#  [31 19 64]
#  [24  8 83]]
#
# Epoch 21
# Train   | loss=0.7684, acc=0.709, macro-F1=0.686
# Test    | loss=1.2109, acc=0.479, macro-F1=0.445
# Train Confusion Matrix:
# [[386   4  72]
#  [ 63 163 270]
#  [  3  16 494]]
# Test Confusion Matrix:
# [[80 23 44]
#  [31 20 63]
#  [26  9 80]]
#
# Epoch 22
# Train   | loss=0.7527, acc=0.714, macro-F1=0.693
# Test    | loss=1.3126, acc=0.479, macro-F1=0.448
# Train Confusion Matrix:
# [[390   3  69]
#  [ 65 172 259]
#  [  4  21 488]]
# Test Confusion Matrix:
# [[81 25 41]
#  [34 22 58]
#  [31  7 77]]
#
# Epoch 23
# Train   | loss=0.7491, acc=0.726, macro-F1=0.711
# Test    | loss=1.2387, acc=0.447, macro-F1=0.418
# Train Confusion Matrix:
# [[386   6  70]
#  [ 30 183 283]
#  [  2  12 499]]
# Test Confusion Matrix:
# [[66 34 47]
#  [24 20 70]
#  [22 11 82]]
# Early stopping at epoch 23
#
# =====
# New tuning parameters:
# hidden_dim: 32
# dropout: 0.6
# learning_rate: 0.001
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 32, batch_first=True)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (fc_hidden): Linear(in_features=32, out_features=16, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=16, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1131, acc=0.365, macro-F1=0.282
# Test    | loss=1.0939, acc=0.383, macro-F1=0.302
# Train Confusion Matrix:
# [[144 318   0]
#  [103 393   0]
#  [ 70 443   0]]
# Test Confusion Matrix:
# [[ 56  91   0]
#  [ 26  88   0]
#  [ 15 100   0]]
#
# Epoch 2
# Train   | loss=1.1029, acc=0.377, macro-F1=0.289
# Test    | loss=1.0911, acc=0.364, macro-F1=0.284
# Train Confusion Matrix:
# [[139 323   0]
#  [ 81 415   0]
#  [ 59 454   0]]
# Test Confusion Matrix:
# [[48 99  0]
#  [25 89  0]
#  [16 99  0]]
#
# Epoch 3
# Train   | loss=1.0925, acc=0.391, macro-F1=0.307
# Test    | loss=1.0893, acc=0.364, macro-F1=0.284
# Train Confusion Matrix:
# [[162 300   0]
#  [ 83 413   0]
#  [ 58 455   0]]
# Test Confusion Matrix:
# [[50 97  0]
#  [27 87  0]
#  [21 94  0]]
#
# Epoch 4
# Train   | loss=1.0913, acc=0.396, macro-F1=0.310
# Test    | loss=1.0873, acc=0.362, macro-F1=0.282
# Train Confusion Matrix:
# [[159 303   0]
#  [ 71 423   2]
#  [ 52 461   0]]
# Test Confusion Matrix:
# [[49 98  0]
#  [27 87  0]
#  [19 96  0]]
#
# Epoch 5
# Train   | loss=1.0773, acc=0.487, macro-F1=0.475
# Test    | loss=1.0799, acc=0.439, macro-F1=0.430
# Train Confusion Matrix:
# [[202 108 152]
#  [111 161 224]
#  [ 63  97 353]]
# Test Confusion Matrix:
# [[62 39 46]
#  [30 34 50]
#  [24 22 69]]
#
# Epoch 6
# Train   | loss=1.0721, acc=0.485, macro-F1=0.467
# Test    | loss=1.0698, acc=0.439, macro-F1=0.417
# Train Confusion Matrix:
# [[228  78 156]
#  [139 126 231]
#  [ 72  81 360]]
# Test Confusion Matrix:
# [[70 30 47]
#  [36 23 55]
#  [26 17 72]]
#
# Epoch 7
# Train   | loss=1.0540, acc=0.493, macro-F1=0.472
# Test    | loss=1.0603, acc=0.439, macro-F1=0.412
# Train Confusion Matrix:
# [[279  74 109]
#  [194 109 193]
#  [ 84  92 337]]
# Test Confusion Matrix:
# [[90 29 28]
#  [53 23 38]
#  [39 24 52]]
#
# Epoch 8
# Train   | loss=1.0369, acc=0.570, macro-F1=0.550
# Test    | loss=1.0616, acc=0.444, macro-F1=0.403
# Train Confusion Matrix:
# [[328  55  79]
#  [183 142 171]
#  [ 69  75 369]]
# Test Confusion Matrix:
# [[101  18  28]
#  [ 61  19  34]
#  [ 42  26  47]]
#
# Epoch 9
# Train   | loss=0.9843, acc=0.606, macro-F1=0.584
# Test    | loss=1.0630, acc=0.444, macro-F1=0.402
# Train Confusion Matrix:
# [[340  48  74]
#  [169 151 176]
#  [ 45  68 400]]
# Test Confusion Matrix:
# [[100  20  27]
#  [ 64  17  33]
#  [ 43  22  50]]
#
# Epoch 10
# Train   | loss=0.9902, acc=0.644, macro-F1=0.626
# Test    | loss=1.0497, acc=0.460, macro-F1=0.429
# Train Confusion Matrix:
# [[367  45  50]
#  [186 175 135]
#  [ 45  62 406]]
# Test Confusion Matrix:
# [[98 23 26]
#  [60 24 30]
#  [39 25 51]]
# Early stopping at epoch 10
#
# =====
# New tuning parameters:
# hidden_dim: 32
# dropout: 0.6
# learning_rate: 0.0005
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 32, batch_first=True)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (fc_hidden): Linear(in_features=32, out_features=16, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=16, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1021, acc=0.314, macro-F1=0.159
# Test    | loss=1.0823, acc=0.391, macro-F1=0.187
# Train Confusion Matrix:
# [[462   0   0]
#  [496   0   0]
#  [513   0   0]]
# Test Confusion Matrix:
# [[147   0   0]
#  [114   0   0]
#  [115   0   0]]
#
# Epoch 2
# Train   | loss=1.0983, acc=0.314, macro-F1=0.159
# Test    | loss=1.0828, acc=0.391, macro-F1=0.187
# Train Confusion Matrix:
# [[462   0   0]
#  [496   0   0]
#  [513   0   0]]
# Test Confusion Matrix:
# [[147   0   0]
#  [114   0   0]
#  [115   0   0]]
#
# Epoch 3
# Train   | loss=1.0930, acc=0.314, macro-F1=0.159
# Test    | loss=1.0829, acc=0.391, macro-F1=0.187
# Train Confusion Matrix:
# [[462   0   0]
#  [496   0   0]
#  [513   0   0]]
# Test Confusion Matrix:
# [[147   0   0]
#  [114   0   0]
#  [115   0   0]]
#
# Epoch 4
# Train   | loss=1.0919, acc=0.314, macro-F1=0.159
# Test    | loss=1.0830, acc=0.388, macro-F1=0.186
# Train Confusion Matrix:
# [[462   0   0]
#  [496   0   0]
#  [513   0   0]]
# Test Confusion Matrix:
# [[146   1   0]
#  [114   0   0]
#  [115   0   0]]
#
# Epoch 5
# Train   | loss=1.0889, acc=0.313, macro-F1=0.159
# Test    | loss=1.0827, acc=0.388, macro-F1=0.186
# Train Confusion Matrix:
# [[461   1   0]
#  [496   0   0]
#  [513   0   0]]
# Test Confusion Matrix:
# [[146   1   0]
#  [114   0   0]
#  [115   0   0]]
#
# Epoch 6
# Train   | loss=1.0871, acc=0.316, macro-F1=0.167
# Test    | loss=1.0827, acc=0.391, macro-F1=0.193
# Train Confusion Matrix:
# [[459   2   1]
#  [490   5   1]
#  [510   2   1]]
# Test Confusion Matrix:
# [[146   1   0]
#  [112   1   1]
#  [115   0   0]]
#
# Epoch 7
# Train   | loss=1.0855, acc=0.445, macro-F1=0.363
# Test    | loss=1.0814, acc=0.434, macro-F1=0.347
# Train Confusion Matrix:
# [[245   6 211]
#  [182   9 305]
#  [107   5 401]]
# Test Confusion Matrix:
# [[76  1 70]
#  [35  1 78]
#  [29  0 86]]
#
# Epoch 8
# Train   | loss=1.0768, acc=0.453, macro-F1=0.376
# Test    | loss=1.0776, acc=0.444, macro-F1=0.364
# Train Confusion Matrix:
# [[244   5 213]
#  [172  17 307]
#  [ 99   8 406]]
# Test Confusion Matrix:
# [[77  1 69]
#  [34  3 77]
#  [27  1 87]]
#
# Epoch 9
# Train   | loss=1.0754, acc=0.458, macro-F1=0.382
# Test    | loss=1.0749, acc=0.436, macro-F1=0.354
# Train Confusion Matrix:
# [[239   6 217]
#  [159  20 317]
#  [ 90   8 415]]
# Test Confusion Matrix:
# [[73  3 71]
#  [34  2 78]
#  [25  1 89]]
#
# Epoch 10
# Train   | loss=1.0711, acc=0.468, macro-F1=0.406
# Test    | loss=1.0753, acc=0.426, macro-F1=0.365
# Train Confusion Matrix:
# [[226  12 224]
#  [136  42 318]
#  [ 80  13 420]]
# Test Confusion Matrix:
# [[65 11 71]
#  [29  7 78]
#  [24  3 88]]
#
# Epoch 11
# Train   | loss=1.0595, acc=0.468, macro-F1=0.399
# Test    | loss=1.0719, acc=0.428, macro-F1=0.360
# Train Confusion Matrix:
# [[235   8 219]
#  [149  32 315]
#  [ 80  12 421]]
# Test Confusion Matrix:
# [[68  8 71]
#  [30  5 79]
#  [24  3 88]]
#
# Epoch 12
# Train   | loss=1.0574, acc=0.468, macro-F1=0.402
# Test    | loss=1.0689, acc=0.434, macro-F1=0.365
# Train Confusion Matrix:
# [[234  14 214]
#  [148  35 313]
#  [ 82  11 420]]
# Test Confusion Matrix:
# [[70 10 67]
#  [31  5 78]
#  [24  3 88]]
#
# Epoch 13
# Train   | loss=1.0568, acc=0.481, macro-F1=0.427
# Test    | loss=1.0705, acc=0.431, macro-F1=0.376
# Train Confusion Matrix:
# [[228  21 213]
#  [124  54 318]
#  [ 67  20 426]]
# Test Confusion Matrix:
# [[65 15 67]
#  [25  9 80]
#  [24  3 88]]
#
# Epoch 14
# Train   | loss=1.0420, acc=0.496, macro-F1=0.441
# Test    | loss=1.0616, acc=0.444, macro-F1=0.387
# Train Confusion Matrix:
# [[260  10 192]
#  [147  54 295]
#  [ 79  18 416]]
# Test Confusion Matrix:
# [[77  8 62]
#  [34  9 71]
#  [29  5 81]]
#
# Epoch 15
# Train   | loss=1.0221, acc=0.521, macro-F1=0.469
# Test    | loss=1.0593, acc=0.463, macro-F1=0.410
# Train Confusion Matrix:
# [[284  12 166]
#  [152  63 281]
#  [ 70  23 420]]
# Test Confusion Matrix:
# [[87 13 47]
#  [38 12 64]
#  [37  3 75]]
#
# Epoch 16
# Train   | loss=1.0132, acc=0.535, macro-F1=0.486
# Test    | loss=1.0652, acc=0.471, macro-F1=0.398
# Train Confusion Matrix:
# [[301  14 147]
#  [155  70 271]
#  [ 69  28 416]]
# Test Confusion Matrix:
# [[100   7  40]
#  [ 52   7  55]
#  [ 41   4  70]]
#
# Epoch 17
# Train   | loss=0.9892, acc=0.562, macro-F1=0.515
# Test    | loss=1.0559, acc=0.465, macro-F1=0.412
# Train Confusion Matrix:
# [[299  18 145]
#  [120  80 296]
#  [ 41  25 447]]
# Test Confusion Matrix:
# [[89 11 47]
#  [37 12 65]
#  [36  5 74]]
#
# Epoch 18
# Train   | loss=0.9774, acc=0.564, macro-F1=0.516
# Test    | loss=1.0587, acc=0.441, macro-F1=0.398
# Train Confusion Matrix:
# [[288  16 158]
#  [ 84  74 338]
#  [ 20  26 467]]
# Test Confusion Matrix:
# [[71 15 61]
#  [29 13 72]
#  [23 10 82]]
#
# Epoch 19
# Train   | loss=0.9496, acc=0.589, macro-F1=0.548
# Test    | loss=1.0671, acc=0.452, macro-F1=0.412
# Train Confusion Matrix:
# [[313  12 137]
#  [105  95 296]
#  [ 26  29 458]]
# Test Confusion Matrix:
# [[77 19 51]
#  [31 15 68]
#  [28  9 78]]
#
# Epoch 20
# Train   | loss=0.9188, acc=0.605, macro-F1=0.567
# Test    | loss=1.0745, acc=0.457, macro-F1=0.421
# Train Confusion Matrix:
# [[320   7 135]
#  [ 97 102 297]
#  [ 15  30 468]]
# Test Confusion Matrix:
# [[75 22 50]
#  [28 17 69]
#  [26  9 80]]
#
# Epoch 21
# Train   | loss=0.8954, acc=0.605, macro-F1=0.571
# Test    | loss=1.0785, acc=0.449, macro-F1=0.409
# Train Confusion Matrix:
# [[312  13 137]
#  [ 69 106 321]
#  [ 11  30 472]]
# Test Confusion Matrix:
# [[70 19 58]
#  [26 15 73]
#  [23  8 84]]
#
# Epoch 22
# Train   | loss=0.8841, acc=0.625, macro-F1=0.595
# Test    | loss=1.0875, acc=0.436, macro-F1=0.399
# Train Confusion Matrix:
# [[320  11 131]
#  [ 56 117 323]
#  [  3  28 482]]
# Test Confusion Matrix:
# [[67 23 57]
#  [28 15 71]
#  [21 12 82]]
#
# Epoch 23
# Train   | loss=0.8747, acc=0.636, macro-F1=0.603
# Test    | loss=1.2024, acc=0.481, macro-F1=0.434
# Train Confusion Matrix:
# [[344   9 109]
#  [103 124 269]
#  [ 17  29 467]]
# Test Confusion Matrix:
# [[95 14 38]
#  [39 16 59]
#  [41  4 70]]
#
# Epoch 24
# Train   | loss=0.8598, acc=0.654, macro-F1=0.631
# Test    | loss=1.2141, acc=0.447, macro-F1=0.402
# Train Confusion Matrix:
# [[342   9 111]
#  [ 80 149 267]
#  [  8  34 471]]
# Test Confusion Matrix:
# [[84 21 42]
#  [41 13 60]
#  [33 11 71]]
#
# Epoch 25
# Train   | loss=0.8459, acc=0.674, macro-F1=0.663
# Test    | loss=1.1405, acc=0.431, macro-F1=0.404
# Train Confusion Matrix:
# [[340   7 115]
#  [ 40 179 277]
#  [  2  39 472]]
# Test Confusion Matrix:
# [[68 32 47]
#  [32 19 63]
#  [24 16 75]]
#
# Epoch 26
# Train   | loss=0.8352, acc=0.638, macro-F1=0.626
# Test    | loss=1.1283, acc=0.431, macro-F1=0.411
# Train Confusion Matrix:
# [[298  34 130]
#  [ 19 162 315]
#  [  1  33 479]]
# Test Confusion Matrix:
# [[53 35 59]
#  [18 26 70]
#  [14 18 83]]
#
# Epoch 27
# Train   | loss=0.8149, acc=0.688, macro-F1=0.679
# Test    | loss=1.1870, acc=0.447, macro-F1=0.427
# Train Confusion Matrix:
# [[346   9 107]
#  [ 31 189 276]
#  [  1  35 477]]
# Test Confusion Matrix:
# [[65 37 45]
#  [27 25 62]
#  [19 18 78]]
#
# Epoch 28
# Train   | loss=0.7851, acc=0.695, macro-F1=0.688
# Test    | loss=1.1709, acc=0.441, macro-F1=0.428
# Train Confusion Matrix:
# [[346   8 108]
#  [ 17 194 285]
#  [  1  30 482]]
# Test Confusion Matrix:
# [[60 36 51]
#  [22 29 63]
#  [14 24 77]]
# Early stopping at epoch 28
#
# =====
# New tuning parameters:
# hidden_dim: 64
# dropout: 0.3
# learning_rate: 0.001
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 64, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc_hidden): Linear(in_features=64, out_features=32, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=32, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1005, acc=0.345, macro-F1=0.196
# Test    | loss=1.1015, acc=0.309, macro-F1=0.172
# Train Confusion Matrix:
# [[  5 443  14]
#  [  1 486   9]
#  [  3 493  17]]
# Test Confusion Matrix:
# [[  1 140   6]
#  [  0 113   1]
#  [  1 112   2]]
#
# Epoch 2
# Train   | loss=1.0915, acc=0.462, macro-F1=0.422
# Test    | loss=1.0907, acc=0.391, macro-F1=0.345
# Train Confusion Matrix:
# [[159  70 233]
#  [ 73  95 328]
#  [ 47  41 425]]
# Test Confusion Matrix:
# [[50 23 74]
#  [25 10 79]
#  [17 11 87]]
#
# Epoch 3
# Train   | loss=1.0564, acc=0.477, macro-F1=0.406
# Test    | loss=1.0710, acc=0.428, macro-F1=0.344
# Train Confusion Matrix:
# [[259   4 199]
#  [161  29 306]
#  [ 89  11 413]]
# Test Confusion Matrix:
# [[83  2 62]
#  [43  1 70]
#  [35  3 77]]
#
# Epoch 4
# Train   | loss=1.0239, acc=0.510, macro-F1=0.463
# Test    | loss=1.0577, acc=0.441, macro-F1=0.385
# Train Confusion Matrix:
# [[278  23 161]
#  [153  66 277]
#  [ 69  38 406]]
# Test Confusion Matrix:
# [[82  9 56]
#  [45  9 60]
#  [33  7 75]]
#
# Epoch 5
# Train   | loss=0.9687, acc=0.579, macro-F1=0.516
# Test    | loss=1.0901, acc=0.436, macro-F1=0.365
# Train Confusion Matrix:
# [[368  15  79]
#  [192  60 244]
#  [ 70  20 423]]
# Test Confusion Matrix:
# [[98 11 38]
#  [58  5 51]
#  [45  9 61]]
#
# Epoch 6
# Train   | loss=0.9037, acc=0.640, macro-F1=0.605
# Test    | loss=1.0993, acc=0.436, macro-F1=0.392
# Train Confusion Matrix:
# [[377  21  64]
#  [148 125 223]
#  [ 38  35 440]]
# Test Confusion Matrix:
# [[94 19 34]
#  [51 14 49]
#  [40 19 56]]
#
# Epoch 7
# Train   | loss=0.8398, acc=0.666, macro-F1=0.635
# Test    | loss=1.2149, acc=0.439, macro-F1=0.394
# Train Confusion Matrix:
# [[406  12  44]
#  [195 147 154]
#  [ 39  47 427]]
# Test Confusion Matrix:
# [[98 21 28]
#  [62 15 37]
#  [48 15 52]]
#
# Epoch 8
# Train   | loss=0.7849, acc=0.658, macro-F1=0.647
# Test    | loss=1.1593, acc=0.418, macro-F1=0.406
# Train Confusion Matrix:
# [[275 103  84]
#  [ 28 211 257]
#  [  4  27 482]]
# Test Confusion Matrix:
# [[59 44 44]
#  [27 28 59]
#  [19 26 70]]
#
# Epoch 9
# Train   | loss=0.7330, acc=0.768, macro-F1=0.766
# Test    | loss=1.2612, acc=0.444, macro-F1=0.441
# Train Confusion Matrix:
# [[348  79  35]
#  [ 25 303 168]
#  [  2  33 478]]
# Test Confusion Matrix:
# [[57 46 44]
#  [24 44 46]
#  [20 29 66]]
#
# Epoch 10
# Train   | loss=0.6334, acc=0.827, macro-F1=0.829
# Test    | loss=1.3696, acc=0.457, macro-F1=0.456
# Train Confusion Matrix:
# [[398  40  24]
#  [ 47 386  63]
#  [  2  78 433]]
# Test Confusion Matrix:
# [[69 55 23]
#  [32 57 25]
#  [26 43 46]]
#
# Epoch 11
# Train   | loss=0.5471, acc=0.861, macro-F1=0.862
# Test    | loss=1.5248, acc=0.449, macro-F1=0.447
# Train Confusion Matrix:
# [[394  42  26]
#  [ 24 398  74]
#  [  1  37 475]]
# Test Confusion Matrix:
# [[70 46 31]
#  [34 44 36]
#  [24 36 55]]
#
# Epoch 12
# Train   | loss=0.4698, acc=0.882, macro-F1=0.883
# Test    | loss=1.5024, acc=0.444, macro-F1=0.446
# Train Confusion Matrix:
# [[381  61  20]
#  [  2 446  48]
#  [  0  43 470]]
# Test Confusion Matrix:
# [[52 67 28]
#  [21 60 33]
#  [19 41 55]]
#
# Epoch 13
# Train   | loss=0.3897, acc=0.899, macro-F1=0.899
# Test    | loss=1.7277, acc=0.420, macro-F1=0.420
# Train Confusion Matrix:
# [[389  54  19]
#  [  1 438  57]
#  [  0  18 495]]
# Test Confusion Matrix:
# [[46 63 38]
#  [19 55 40]
#  [16 42 57]]
#
# Epoch 14
# Train   | loss=0.3709, acc=0.923, macro-F1=0.924
# Test    | loss=1.9672, acc=0.441, macro-F1=0.443
# Train Confusion Matrix:
# [[419  27  16]
#  [  9 450  37]
#  [  1  23 489]]
# Test Confusion Matrix:
# [[60 62 25]
#  [30 57 27]
#  [23 43 49]]
#
# Epoch 15
# Train   | loss=0.3264, acc=0.931, macro-F1=0.931
# Test    | loss=2.1035, acc=0.426, macro-F1=0.426
# Train Confusion Matrix:
# [[423  21  18]
#  [  7 445  44]
#  [  0  12 501]]
# Test Confusion Matrix:
# [[57 52 38]
#  [27 47 40]
#  [21 38 56]]
# Early stopping at epoch 15
#
# =====
# New tuning parameters:
# hidden_dim: 64
# dropout: 0.3
# learning_rate: 0.0005
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 64, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc_hidden): Linear(in_features=64, out_features=32, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=32, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1019, acc=0.339, macro-F1=0.174
# Test    | loss=1.1008, acc=0.303, macro-F1=0.156
# Train Confusion Matrix:
# [[  2 458   2]
#  [  0 495   1]
#  [  1 510   2]]
# Test Confusion Matrix:
# [[  0 146   1]
#  [  0 114   0]
#  [  1 114   0]]
#
# Epoch 2
# Train   | loss=1.0946, acc=0.430, macro-F1=0.356
# Test    | loss=1.0967, acc=0.351, macro-F1=0.306
# Train Confusion Matrix:
# [[ 27 210 225]
#  [  2 193 301]
#  [ 17  84 412]]
# Test Confusion Matrix:
# [[ 9 69 69]
#  [ 0 40 74]
#  [ 3 29 83]]
#
# Epoch 3
# Train   | loss=1.0873, acc=0.453, macro-F1=0.401
# Test    | loss=1.0930, acc=0.372, macro-F1=0.341
# Train Confusion Matrix:
# [[ 78 143 241]
#  [ 17 152 327]
#  [ 31  46 436]]
# Test Confusion Matrix:
# [[24 49 74]
#  [ 4 29 81]
#  [ 9 19 87]]
#
# Epoch 4
# Train   | loss=1.0705, acc=0.480, macro-F1=0.454
# Test    | loss=1.0763, acc=0.431, macro-F1=0.412
# Train Confusion Matrix:
# [[189  83 190]
#  [ 98 122 276]
#  [ 72  46 395]]
# Test Confusion Matrix:
# [[64 27 56]
#  [28 25 61]
#  [28 14 73]]
#
# Epoch 5
# Train   | loss=1.0486, acc=0.481, macro-F1=0.438
# Test    | loss=1.0533, acc=0.444, macro-F1=0.395
# Train Confusion Matrix:
# [[292  52 118]
#  [228  63 205]
#  [131  30 352]]
# Test Confusion Matrix:
# [[96 21 30]
#  [61 12 41]
#  [45 11 59]]
#
# Epoch 6
# Train   | loss=1.0191, acc=0.511, macro-F1=0.454
# Test    | loss=1.0524, acc=0.447, macro-F1=0.363
# Train Confusion Matrix:
# [[371  19  72]
#  [271  48 177]
#  [146  34 333]]
# Test Confusion Matrix:
# [[120  11  16]
#  [ 77   7  30]
#  [ 68   6  41]]
#
# Epoch 7
# Train   | loss=0.9959, acc=0.534, macro-F1=0.461
# Test    | loss=1.0721, acc=0.439, macro-F1=0.342
# Train Confusion Matrix:
# [[404  10  48]
#  [299  32 165]
#  [142  22 349]]
# Test Confusion Matrix:
# [[125   9  13]
#  [ 82   5  27]
#  [ 76   4  35]]
#
# Epoch 8
# Train   | loss=0.9547, acc=0.545, macro-F1=0.476
# Test    | loss=1.1310, acc=0.441, macro-F1=0.334
# Train Confusion Matrix:
# [[416   4  42]
#  [335  38 123]
#  [148  17 348]]
# Test Confusion Matrix:
# [[132   5  10]
#  [ 94   5  15]
#  [ 82   4  29]]
#
# Epoch 9
# Train   | loss=0.9178, acc=0.601, macro-F1=0.544
# Test    | loss=1.1310, acc=0.439, macro-F1=0.351
# Train Confusion Matrix:
# [[392  18  52]
#  [256  74 166]
#  [ 72  23 418]]
# Test Confusion Matrix:
# [[118   8  21]
#  [ 83   5  26]
#  [ 69   4  42]]
# Early stopping at epoch 9
#
# =====
# New tuning parameters:
# hidden_dim: 64
# dropout: 0.5
# learning_rate: 0.001
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 64, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc_hidden): Linear(in_features=64, out_features=32, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=32, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1032, acc=0.337, macro-F1=0.168
# Test    | loss=1.1035, acc=0.303, macro-F1=0.155
# Train Confusion Matrix:
# [[  0 462   0]
#  [  0 496   0]
#  [  0 513   0]]
# Test Confusion Matrix:
# [[  0 147   0]
#  [  0 114   0]
#  [  0 115   0]]
#
# Epoch 2
# Train   | loss=1.0957, acc=0.357, macro-F1=0.223
# Test    | loss=1.0994, acc=0.303, macro-F1=0.169
# Train Confusion Matrix:
# [[ 40 421   1]
#  [ 11 483   2]
#  [  9 502   2]]
# Test Confusion Matrix:
# [[  2 145   0]
#  [  3 111   0]
#  [  5 109   1]]
#
# Epoch 3
# Train   | loss=1.0870, acc=0.479, macro-F1=0.440
# Test    | loss=1.0865, acc=0.423, macro-F1=0.395
# Train Confusion Matrix:
# [[206  36 220]
#  [102  83 311]
#  [ 65  32 416]]
# Test Confusion Matrix:
# [[51 25 71]
#  [13 21 80]
#  [21  7 87]]
#
# Epoch 4
# Train   | loss=1.0577, acc=0.497, macro-F1=0.451
# Test    | loss=1.0681, acc=0.447, macro-F1=0.420
# Train Confusion Matrix:
# [[259  28 175]
#  [154  68 274]
#  [ 82  27 404]]
# Test Confusion Matrix:
# [[61 24 62]
#  [19 22 73]
#  [20 10 85]]
#
# Epoch 5
# Train   | loss=0.9961, acc=0.549, macro-F1=0.509
# Test    | loss=1.0726, acc=0.420, macro-F1=0.393
# Train Confusion Matrix:
# [[267  33 162]
#  [105  93 298]
#  [ 43  22 448]]
# Test Confusion Matrix:
# [[46 31 70]
#  [18 23 73]
#  [11 15 89]]
#
# Epoch 6
# Train   | loss=0.9697, acc=0.582, macro-F1=0.538
# Test    | loss=1.0458, acc=0.468, macro-F1=0.442
# Train Confusion Matrix:
# [[356  22  84]
#  [185  89 222]
#  [ 56  46 411]]
# Test Confusion Matrix:
# [[69 24 54]
#  [31 24 59]
#  [18 14 83]]
#
# Epoch 7
# Train   | loss=0.9220, acc=0.576, macro-F1=0.547
# Test    | loss=1.0848, acc=0.423, macro-F1=0.401
# Train Confusion Matrix:
# [[258  52 152]
#  [ 64 121 311]
#  [ 15  30 468]]
# Test Confusion Matrix:
# [[36 42 69]
#  [ 9 34 71]
#  [ 8 18 89]]
#
# Epoch 8
# Train   | loss=0.8732, acc=0.649, macro-F1=0.619
# Test    | loss=1.0511, acc=0.473, macro-F1=0.453
# Train Confusion Matrix:
# [[378  22  62]
#  [143 141 212]
#  [ 29  49 435]]
# Test Confusion Matrix:
# [[73 31 43]
#  [33 26 55]
#  [13 23 79]]
#
# Epoch 9
# Train   | loss=0.8090, acc=0.710, macro-F1=0.690
# Test    | loss=1.0966, acc=0.436, macro-F1=0.427
# Train Confusion Matrix:
# [[398  17  47]
#  [109 190 197]
#  [ 14  43 456]]
# Test Confusion Matrix:
# [[56 50 41]
#  [26 32 56]
#  [11 28 76]]
#
# Epoch 10
# Train   | loss=0.7495, acc=0.734, macro-F1=0.720
# Test    | loss=1.1543, acc=0.452, macro-F1=0.452
# Train Confusion Matrix:
# [[406  22  34]
#  [109 222 165]
#  [  8  53 452]]
# Test Confusion Matrix:
# [[56 58 33]
#  [31 45 38]
#  [12 34 69]]
#
# Epoch 11
# Train   | loss=0.6992, acc=0.763, macro-F1=0.760
# Test    | loss=1.2221, acc=0.423, macro-F1=0.405
# Train Confusion Matrix:
# [[370  50  42]
#  [ 11 256 229]
#  [  2  14 497]]
# Test Confusion Matrix:
# [[31 66 50]
#  [15 43 56]
#  [ 6 24 85]]
#
# Epoch 12
# Train   | loss=0.6049, acc=0.834, macro-F1=0.833
# Test    | loss=1.3180, acc=0.484, macro-F1=0.484
# Train Confusion Matrix:
# [[414  19  29]
#  [ 36 330 130]
#  [  3  27 483]]
# Test Confusion Matrix:
# [[48 67 32]
#  [18 63 33]
#  [ 6 38 71]]
#
# Epoch 13
# Train   | loss=0.5681, acc=0.854, macro-F1=0.853
# Test    | loss=1.3632, acc=0.468, macro-F1=0.463
# Train Confusion Matrix:
# [[415  19  28]
#  [ 23 345 128]
#  [  3  14 496]]
# Test Confusion Matrix:
# [[41 72 34]
#  [18 57 39]
#  [ 5 32 78]]
#
# Epoch 14
# Train   | loss=0.5194, acc=0.853, macro-F1=0.852
# Test    | loss=1.5277, acc=0.460, macro-F1=0.457
# Train Confusion Matrix:
# [[418  17  27]
#  [ 32 346 118]
#  [  2  20 491]]
# Test Confusion Matrix:
# [[42 70 35]
#  [16 57 41]
#  [ 6 35 74]]
#
# Epoch 15
# Train   | loss=0.5485, acc=0.857, macro-F1=0.858
# Test    | loss=1.4567, acc=0.436, macro-F1=0.427
# Train Confusion Matrix:
# [[394  45  23]
#  [  3 367 126]
#  [  1  13 499]]
# Test Confusion Matrix:
# [[31 83 33]
#  [14 58 42]
#  [ 5 35 75]]
#
# Epoch 16
# Train   | loss=0.4692, acc=0.881, macro-F1=0.883
# Test    | loss=1.6530, acc=0.444, macro-F1=0.445
# Train Confusion Matrix:
# [[424  21  17]
#  [ 12 402  82]
#  [  2  41 470]]
# Test Confusion Matrix:
# [[40 87 20]
#  [17 70 27]
#  [ 6 52 57]]
#
# Epoch 17
# Train   | loss=0.4413, acc=0.898, macro-F1=0.900
# Test    | loss=1.6370, acc=0.444, macro-F1=0.438
# Train Confusion Matrix:
# [[425  20  17]
#  [  6 405  85]
#  [  1  21 491]]
# Test Confusion Matrix:
# [[34 83 30]
#  [16 61 37]
#  [ 6 37 72]]
# Early stopping at epoch 17
#
# =====
# New tuning parameters:
# hidden_dim: 64
# dropout: 0.5
# learning_rate: 0.0005
#
# max_len: 32
#
# embed_dim: 50
#
# CaptionRNN(
#   (embedding): Embedding(9991, 50, padding_idx=0)
#   (lstm): LSTM(50, 64, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc_hidden): Linear(in_features=64, out_features=32, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=32, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1017, acc=0.337, macro-F1=0.169
# Test    | loss=1.1085, acc=0.303, macro-F1=0.155
# Train Confusion Matrix:
# [[  0 461   1]
#  [  0 495   1]
#  [  0 512   1]]
# Test Confusion Matrix:
# [[  0 147   0]
#  [  0 114   0]
#  [  0 115   0]]
#
# Epoch 2
# Train   | loss=1.0988, acc=0.336, macro-F1=0.170
# Test    | loss=1.1046, acc=0.306, macro-F1=0.161
# Train Confusion Matrix:
# [[  0 455   7]
#  [  1 492   3]
#  [  0 511   2]]
# Test Confusion Matrix:
# [[  1 144   2]
#  [  0 114   0]
#  [  0 115   0]]
#
# Epoch 3
# Train   | loss=1.0952, acc=0.356, macro-F1=0.219
# Test    | loss=1.1017, acc=0.303, macro-F1=0.168
# Train Confusion Matrix:
# [[ 34 422   6]
#  [  5 485   6]
#  [  1 508   4]]
# Test Confusion Matrix:
# [[  3 141   3]
#  [  0 111   3]
#  [  2 113   0]]
#
# Epoch 4
# Train   | loss=1.0921, acc=0.385, macro-F1=0.285
# Test    | loss=1.0977, acc=0.330, macro-F1=0.214
# Train Confusion Matrix:
# [[ 96 362   4]
#  [ 28 465   3]
#  [ 18 489   6]]
# Test Confusion Matrix:
# [[ 15 132   0]
#  [  5 109   0]
#  [  5 110   0]]
#
# Epoch 5
# Train   | loss=1.0883, acc=0.415, macro-F1=0.338
# Test    | loss=1.0910, acc=0.359, macro-F1=0.273
# Train Confusion Matrix:
# [[180 279   3]
#  [ 67 424   5]
#  [ 49 457   7]]
# Test Confusion Matrix:
# [[ 35 111   1]
#  [ 14  99   1]
#  [ 11 103   1]]
#
# Epoch 6
# Train   | loss=1.0756, acc=0.479, macro-F1=0.429
# Test    | loss=1.0764, acc=0.415, macro-F1=0.361
# Train Confusion Matrix:
# [[238  16 208]
#  [136  60 300]
#  [ 93  14 406]]
# Test Confusion Matrix:
# [[70 12 65]
#  [37  8 69]
#  [31  6 78]]
#
# Epoch 7
# Train   | loss=1.0565, acc=0.475, macro-F1=0.412
# Test    | loss=1.0551, acc=0.449, macro-F1=0.368
# Train Confusion Matrix:
# [[286   9 167]
#  [199  36 261]
#  [120  16 377]]
# Test Confusion Matrix:
# [[103   6  38]
#  [ 60   4  50]
#  [ 49   4  62]]
#
# Epoch 8
# Train   | loss=1.0326, acc=0.506, macro-F1=0.452
# Test    | loss=1.0524, acc=0.452, macro-F1=0.369
# Train Confusion Matrix:
# [[317  13 132]
#  [201  55 240]
#  [116  25 372]]
# Test Confusion Matrix:
# [[114  10  23]
#  [ 71   5  38]
#  [ 59   5  51]]
#
# Epoch 9
# Train   | loss=1.0258, acc=0.530, macro-F1=0.479
# Test    | loss=1.0527, acc=0.468, macro-F1=0.395
# Train Confusion Matrix:
# [[352   9 101]
#  [208  65 223]
#  [126  25 362]]
# Test Confusion Matrix:
# [[117  10  20]
#  [ 69  10  35]
#  [ 61   5  49]]
#
# Epoch 10
# Train   | loss=0.9852, acc=0.545, macro-F1=0.483
# Test    | loss=1.1774, acc=0.441, macro-F1=0.334
# Train Confusion Matrix:
# [[389   7  66]
#  [245  53 198]
#  [134  20 359]]
# Test Confusion Matrix:
# [[128   5  14]
#  [ 87   3  24]
#  [ 77   3  35]]
#
# Epoch 11
# Train   | loss=0.9648, acc=0.597, macro-F1=0.559
# Test    | loss=1.0795, acc=0.460, macro-F1=0.398
# Train Confusion Matrix:
# [[350  25  87]
#  [147 107 242]
#  [ 64  28 421]]
# Test Confusion Matrix:
# [[112  12  23]
#  [ 64  13  37]
#  [ 58   9  48]]
#
# Epoch 12
# Train   | loss=0.9165, acc=0.632, macro-F1=0.593
# Test    | loss=1.1225, acc=0.452, macro-F1=0.411
# Train Confusion Matrix:
# [[368  25  69]
#  [124 111 261]
#  [ 31  31 451]]
# Test Confusion Matrix:
# [[99 22 26]
#  [59 18 37]
#  [55  7 53]]
#
# Epoch 13
# Train   | loss=0.8731, acc=0.645, macro-F1=0.598
# Test    | loss=1.1739, acc=0.455, macro-F1=0.409
# Train Confusion Matrix:
# [[393  13  56]
#  [161 103 232]
#  [ 32  28 453]]
# Test Confusion Matrix:
# [[105  18  24]
#  [ 64  18  32]
#  [ 61   6  48]]
#
# Epoch 14
# Train   | loss=0.8358, acc=0.680, macro-F1=0.657
# ...
# Early stopping at epoch 15
#
# =====
# New tuning parameters:
# hidden_dim: 128
# dropout: 0.3
# learning_rate: 0.0005
#
# max_len: 128
#
# embed_dim: 100
#
# CaptionRNN(
#   (embedding): Embedding(9991, 100, padding_idx=0)
#   (lstm): LSTM(100, 128, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc_hidden): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=64, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.0996, acc=0.328, macro-F1=0.194
# Test    | loss=1.0959, acc=0.391, macro-F1=0.198
# Train Confusion Matrix:
# [[457   5   0]
#  [475  20   1]
#  [505   2   6]]
# Test Confusion Matrix:
# [[145   0   2]
#  [111   2   1]
#  [114   1   0]]
#
# Epoch 2
# Train   | loss=1.0972, acc=0.368, macro-F1=0.234
# Test    | loss=1.0987, acc=0.316, macro-F1=0.193
# Train Confusion Matrix:
# [[ 35 423   4]
#  [  2 494   0]
#  [  5 496  12]]
# Test Confusion Matrix:
# [[  9 134   4]
#  [  3 110   1]
#  [  4 111   0]]
#
# Epoch 3
# Train   | loss=1.0955, acc=0.370, macro-F1=0.239
# Test    | loss=1.0985, acc=0.314, macro-F1=0.189
# Train Confusion Matrix:
# [[ 37 422   3]
#  [  2 494   0]
#  [  5 494  14]]
# Test Confusion Matrix:
# [[  8 135   4]
#  [  3 110   1]
#  [  4 111   0]]
#
# Epoch 4
# Train   | loss=1.0933, acc=0.345, macro-F1=0.224
# Test    | loss=1.0974, acc=0.383, macro-F1=0.196
# Train Confusion Matrix:
# [[458   2   2]
#  [463  33   0]
#  [496   1  16]]
# Test Confusion Matrix:
# [[142   1   4]
#  [111   2   1]
#  [113   2   0]]
#
# Epoch 5
# Train   | loss=1.0883, acc=0.373, macro-F1=0.242
# Test    | loss=1.0994, acc=0.316, macro-F1=0.193
# Train Confusion Matrix:
# [[ 39 421   2]
#  [  0 496   0]
#  [  5 494  14]]
# Test Confusion Matrix:
# [[  9 135   3]
#  [  2 110   2]
#  [  4 111   0]]
#
# Epoch 6
# Train   | loss=1.0792, acc=0.373, macro-F1=0.242
# Test    | loss=1.0994, acc=0.314, macro-F1=0.192
# Train Confusion Matrix:
# [[ 40 420   2]
#  [  1 495   0]
#  [  7 493  13]]
# Test Confusion Matrix:
# [[  9 134   4]
#  [  2 109   3]
#  [  4 111   0]]
# Early stopping at epoch 6
#
# =====
# New tuning parameters:
# hidden_dim: 128
# dropout: 0.5
# learning_rate: 0.001
#
# max_len: 128
#
# embed_dim: 100
#
# CaptionRNN(
#   (embedding): Embedding(9991, 100, padding_idx=0)
#   (lstm): LSTM(100, 128, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc_hidden): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=64, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1004, acc=0.327, macro-F1=0.193
# Test    | loss=1.0961, acc=0.391, macro-F1=0.193
# Train Confusion Matrix:
# [[456   2   4]
#  [473  13  10]
#  [500   1  12]]
# Test Confusion Matrix:
# [[146   0   1]
#  [112   1   1]
#  [115   0   0]]
#
# Epoch 2
# Train   | loss=1.0992, acc=0.384, macro-F1=0.253
# Test    | loss=1.0975, acc=0.316, macro-F1=0.197
# Train Confusion Matrix:
# [[ 37   1 424]
#  [  9  22 465]
#  [  7   0 506]]
# Test Confusion Matrix:
# [[  9   1 137]
#  [  3   1 110]
#  [  5   1 109]]
#
# Epoch 3
# Train   | loss=1.0949, acc=0.390, macro-F1=0.261
# Test    | loss=1.0986, acc=0.316, macro-F1=0.199
# Train Confusion Matrix:
# [[ 34   3 425]
#  [  4  30 462]
#  [  3   1 509]]
# Test Confusion Matrix:
# [[  8   3 136]
#  [  2   2 110]
#  [  5   1 109]]
#
# Epoch 4
# Train   | loss=1.0907, acc=0.394, macro-F1=0.271
# Test    | loss=1.0989, acc=0.314, macro-F1=0.195
# Train Confusion Matrix:
# [[ 40   0 422]
#  [  1  33 462]
#  [  4   3 506]]
# Test Confusion Matrix:
# [[  7   5 135]
#  [  2   2 110]
#  [  5   1 109]]
#
# Epoch 5
# Train   | loss=1.0794, acc=0.394, macro-F1=0.272
# Test    | loss=1.1015, acc=0.314, macro-F1=0.195
# Train Confusion Matrix:
# [[ 39   2 421]
#  [  2  35 459]
#  [  5   2 506]]
# Test Confusion Matrix:
# [[  7   5 135]
#  [  2   2 110]
#  [  4   2 109]]
#
# Epoch 6
# Train   | loss=1.0662, acc=0.397, macro-F1=0.275
# Test    | loss=1.1067, acc=0.309, macro-F1=0.186
# Train Confusion Matrix:
# [[ 39   0 423]
#  [  0  36 460]
#  [  4   0 509]]
# Test Confusion Matrix:
# [[  5   3 139]
#  [  1   2 111]
#  [  5   1 109]]
#
# Epoch 7
# Train   | loss=1.0534, acc=0.399, macro-F1=0.278
# Test    | loss=1.1084, acc=0.311, macro-F1=0.189
# Train Confusion Matrix:
# [[ 41   0 421]
#  [  0  36 460]
#  [  3   0 510]]
# Test Confusion Matrix:
# [[  7   3 137]
#  [  1   1 112]
#  [  4   2 109]]
#
# Epoch 8
# Train   | loss=1.0441, acc=0.401, macro-F1=0.279
# Test    | loss=1.1069, acc=0.309, macro-F1=0.184
# Train Confusion Matrix:
# [[ 43   0 419]
#  [  2  34 460]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  6   2 139]
#  [  2   1 111]
#  [  4   2 109]]
# Early stopping at epoch 8
#
# =====
# New tuning parameters:
# hidden_dim: 128
# dropout: 0.5
# learning_rate: 0.0005
#
# max_len: 128
#
# embed_dim: 100
#
# CaptionRNN(
#   (embedding): Embedding(9991, 100, padding_idx=0)
#   (lstm): LSTM(100, 128, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc_hidden): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=64, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1028, acc=0.349, macro-F1=0.172
# Test    | loss=1.1076, acc=0.306, macro-F1=0.156
# Train Confusion Matrix:
# [[  0   1 461]
#  [  0   0 496]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  0   0 147]
#  [  0   0 114]
#  [  0   0 115]]
#
# Epoch 2
# Train   | loss=1.0985, acc=0.362, macro-F1=0.200
# Test    | loss=1.1033, acc=0.309, macro-F1=0.165
# Train Confusion Matrix:
# [[ 10   1 451]
#  [  0   9 487]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  2   0 145]
#  [  0   0 114]
#  [  0   1 114]]
#
# Epoch 3
# Train   | loss=1.0986, acc=0.384, macro-F1=0.248
# Test    | loss=1.1002, acc=0.301, macro-F1=0.162
# Train Confusion Matrix:
# [[ 33   0 429]
#  [  8  21 467]
#  [  2   0 511]]
# Test Confusion Matrix:
# [[  2   1 144]
#  [  1   0 113]
#  [  4   0 111]]
#
# Epoch 4
# Train   | loss=1.0967, acc=0.388, macro-F1=0.256
# Test    | loss=1.1019, acc=0.301, macro-F1=0.166
# Train Confusion Matrix:
# [[ 34   1 427]
#  [  4  26 466]
#  [  1   1 511]]
# Test Confusion Matrix:
# [[  3   2 142]
#  [  0   0 114]
#  [  3   2 110]]
#
# Epoch 5
# Train   | loss=1.0927, acc=0.340, macro-F1=0.211
# Test    | loss=1.0972, acc=0.375, macro-F1=0.187
# Train Confusion Matrix:
# [[462   0   0]
#  [474  20   2]
#  [495   0  18]]
# Test Confusion Matrix:
# [[140   1   6]
#  [112   1   1]
#  [115   0   0]]
#
# Epoch 6
# Train   | loss=1.0918, acc=0.343, macro-F1=0.218
# Test    | loss=1.0985, acc=0.375, macro-F1=0.188
# Train Confusion Matrix:
# [[460   0   2]
#  [469  26   1]
#  [493   2  18]]
# Test Confusion Matrix:
# [[140   1   6]
#  [112   1   1]
#  [114   1   0]]
#
# Epoch 7
# Train   | loss=1.0866, acc=0.393, macro-F1=0.268
# Test    | loss=1.1016, acc=0.316, macro-F1=0.199
# Train Confusion Matrix:
# [[ 42   0 420]
#  [  8  28 460]
#  [  1   4 508]]
# Test Confusion Matrix:
# [[  8   4 135]
#  [  4   2 108]
#  [  4   2 109]]
#
# Epoch 8
# Train   | loss=1.0864, acc=0.396, macro-F1=0.271
# Test    | loss=1.1107, acc=0.306, macro-F1=0.182
# Train Confusion Matrix:
# [[ 39   2 421]
#  [  1  33 462]
#  [  1   2 510]]
# Test Confusion Matrix:
# [[  4   5 138]
#  [  2   2 110]
#  [  3   3 109]]
#
# Epoch 9
# Train   | loss=1.0789, acc=0.394, macro-F1=0.270
# Test    | loss=1.1064, acc=0.322, macro-F1=0.207
# Train Confusion Matrix:
# [[ 39   2 421]
#  [  2  32 462]
#  [  1   3 509]]
# Test Confusion Matrix:
# [[ 10   3 134]
#  [  2   2 110]
#  [  4   2 109]]
#
# Epoch 10
# Train   | loss=1.0684, acc=0.398, macro-F1=0.277
# Test    | loss=1.1113, acc=0.324, macro-F1=0.211
# Train Confusion Matrix:
# [[ 42   0 420]
#  [  1  34 461]
#  [  1   2 510]]
# Test Confusion Matrix:
# [[ 11   2 134]
#  [  3   2 109]
#  [  4   2 109]]
#
# Epoch 11
# Train   | loss=1.0569, acc=0.399, macro-F1=0.278
# Test    | loss=1.1219, acc=0.324, macro-F1=0.211
# Train Confusion Matrix:
# [[ 42   1 419]
#  [  0  35 461]
#  [  1   2 510]]
# Test Confusion Matrix:
# [[ 11   2 134]
#  [  2   2 110]
#  [  4   2 109]]
#
# Epoch 12
# Train   | loss=1.0507, acc=0.401, macro-F1=0.281
# Test    | loss=1.1372, acc=0.327, macro-F1=0.215
# Train Confusion Matrix:
# [[ 44   0 418]
#  [  2  35 459]
#  [  1   1 511]]
# Test Confusion Matrix:
# [[ 12   2 133]
#  [  4   2 108]
#  [  4   2 109]]
#
# Epoch 13
# Train   | loss=1.0496, acc=0.402, macro-F1=0.280
# Test    | loss=1.1277, acc=0.322, macro-F1=0.207
# Train Confusion Matrix:
# [[ 43   0 419]
#  [  0  35 461]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[ 10   2 135]
#  [  2   2 110]
#  [  5   1 109]]
#
# Epoch 14
# Train   | loss=1.0386, acc=0.402, macro-F1=0.282
# Test    | loss=1.1345, acc=0.327, macro-F1=0.219
# Train Confusion Matrix:
# [[ 44   0 418]
#  [  1  36 459]
#  [  1   0 512]]
# Test Confusion Matrix:
# [[ 10   3 134]
#  [  2   4 108]
#  [  4   2 109]]
#
# Epoch 15
# Train   | loss=1.0342, acc=0.402, macro-F1=0.282
# Test    | loss=1.1493, acc=0.324, macro-F1=0.210
# Train Confusion Matrix:
# [[ 44   0 418]
#  [  1  36 459]
#  [  1   0 512]]
# Test Confusion Matrix:
# [[  9   3 135]
#  [  2   3 109]
#  [  4   1 110]]
#
# Epoch 16
# Train   | loss=1.0331, acc=0.404, macro-F1=0.285
# Test    | loss=1.1379, acc=0.324, macro-F1=0.208
# Train Confusion Matrix:
# [[ 46   0 416]
#  [  0  36 460]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[ 10   0 137]
#  [  3   2 109]
#  [  4   1 110]]
#
# Epoch 17
# Train   | loss=1.0327, acc=0.405, macro-F1=0.287
# Test    | loss=1.1470, acc=0.324, macro-F1=0.208
# Train Confusion Matrix:
# [[ 48   0 414]
#  [  0  36 460]
#  [  1   0 512]]
# Test Confusion Matrix:
# [[ 10   0 137]
#  [  4   2 108]
#  [  4   1 110]]
#
# Epoch 18
# Train   | loss=1.0278, acc=0.409, macro-F1=0.295
# Test    | loss=1.1578, acc=0.327, macro-F1=0.212
# Train Confusion Matrix:
# [[ 54   0 408]
#  [  0  36 460]
#  [  1   0 512]]
# Test Confusion Matrix:
# [[ 11   1 135]
#  [  4   2 108]
#  [  4   1 110]]
#
# Epoch 19
# Train   | loss=1.0247, acc=0.404, macro-F1=0.285
# Test    | loss=1.1515, acc=0.324, macro-F1=0.205
# Train Confusion Matrix:
# [[ 46   1 415]
#  [  0  36 460]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  9   0 138]
#  [  3   2 109]
#  [  3   1 111]]
# Early stopping at epoch 19
#
# =====
# New tuning parameters:
# hidden_dim: 128
# dropout: 0.6
# learning_rate: 0.001
#
# max_len: 128
#
# embed_dim: 100
#
# CaptionRNN(
#   (embedding): Embedding(9991, 100, padding_idx=0)
#   (lstm): LSTM(100, 128, batch_first=True)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (fc_hidden): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=64, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1003, acc=0.375, macro-F1=0.238
# Test    | loss=1.1009, acc=0.306, macro-F1=0.172
# Train Confusion Matrix:
# [[ 27   8 427]
#  [ 10  21 465]
#  [  4   6 503]]
# Test Confusion Matrix:
# [[  4   3 140]
#  [  2   0 112]
#  [  2   2 111]]
#
# Epoch 2
# Train   | loss=1.0978, acc=0.383, macro-F1=0.250
# Test    | loss=1.1037, acc=0.303, macro-F1=0.173
# Train Confusion Matrix:
# [[ 31   4 427]
#  [  6  26 464]
#  [  3   4 506]]
# Test Confusion Matrix:
# [[  3   4 140]
#  [  4   1 109]
#  [  3   2 110]]
#
# Epoch 3
# Train   | loss=1.0952, acc=0.364, macro-F1=0.234
# Test    | loss=1.1012, acc=0.306, macro-F1=0.175
# Train Confusion Matrix:
# [[ 38 422   2]
#  [  7 487   2]
#  [  5 497  11]]
# Test Confusion Matrix:
# [[  5 140   2]
#  [  4 110   0]
#  [  4 111   0]]
#
# Epoch 4
# Train   | loss=1.0943, acc=0.366, macro-F1=0.237
# Test    | loss=1.0999, acc=0.314, macro-F1=0.187
# Train Confusion Matrix:
# [[ 41 421   0]
#  [ 10 486   0]
#  [  4 498  11]]
# Test Confusion Matrix:
# [[  8 139   0]
#  [  4 110   0]
#  [  4 111   0]]
#
# Epoch 5
# Train   | loss=1.0888, acc=0.390, macro-F1=0.265
# Test    | loss=1.1034, acc=0.316, macro-F1=0.199
# Train Confusion Matrix:
# [[ 41   0 421]
#  [  8  28 460]
#  [  2   7 504]]
# Test Confusion Matrix:
# [[  8   5 134]
#  [  4   2 108]
#  [  5   1 109]]
#
# Epoch 6
# Train   | loss=1.0730, acc=0.394, macro-F1=0.272
# Test    | loss=1.1071, acc=0.319, macro-F1=0.201
# Train Confusion Matrix:
# [[ 40   0 422]
#  [  1  33 462]
#  [  1   5 507]]
# Test Confusion Matrix:
# [[  8   5 134]
#  [  3   2 109]
#  [  3   2 110]]
#
# Epoch 7
# Train   | loss=1.0661, acc=0.396, macro-F1=0.274
# Test    | loss=1.1079, acc=0.316, macro-F1=0.199
# Train Confusion Matrix:
# [[ 40   0 422]
#  [  0  34 462]
#  [  1   3 509]]
# Test Confusion Matrix:
# [[  8   4 135]
#  [  3   2 109]
#  [  4   2 109]]
#
# Epoch 8
# Train   | loss=1.0562, acc=0.400, macro-F1=0.278
# Test    | loss=1.1145, acc=0.322, macro-F1=0.205
# Train Confusion Matrix:
# [[ 42   0 420]
#  [  0  34 462]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  9   3 135]
#  [  4   2 108]
#  [  3   2 110]]
#
# Epoch 9
# Train   | loss=1.0431, acc=0.403, macro-F1=0.283
# Test    | loss=1.1375, acc=0.319, macro-F1=0.198
# Train Confusion Matrix:
# [[ 43   1 418]
#  [  0  37 459]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  9   2 136]
#  [  4   1 109]
#  [  4   1 110]]
#
# Epoch 10
# Train   | loss=1.0363, acc=0.350, macro-F1=0.233
# Test    | loss=1.1177, acc=0.383, macro-F1=0.196
# Train Confusion Matrix:
# [[459   3   0]
#  [460  35   1]
#  [491   1  21]]
# Test Confusion Matrix:
# [[142   2   3]
#  [112   1   1]
#  [112   2   1]]
#
# Epoch 11
# Train   | loss=1.0420, acc=0.403, macro-F1=0.284
# Test    | loss=1.1608, acc=0.314, macro-F1=0.190
# Train Confusion Matrix:
# [[ 44   0 418]
#  [  0  37 459]
#  [  1   0 512]]
# Test Confusion Matrix:
# [[  7   3 137]
#  [  4   1 109]
#  [  3   2 110]]
#
# Epoch 12
# Train   | loss=1.0319, acc=0.405, macro-F1=0.287
# Test    | loss=1.1447, acc=0.316, macro-F1=0.194
# Train Confusion Matrix:
# [[ 46   0 416]
#  [  0  37 459]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  8   2 137]
#  [  4   1 109]
#  [  3   2 110]]
#
# Epoch 13
# Train   | loss=1.0507, acc=0.411, macro-F1=0.299
# Test    | loss=1.2303, acc=0.324, macro-F1=0.204
# Train Confusion Matrix:
# [[ 57   0 405]
#  [  4  37 455]
#  [  3   0 510]]
# Test Confusion Matrix:
# [[ 10   3 134]
#  [  6   1 107]
#  [  3   1 111]]
# Early stopping at epoch 13
#
# =====
# New tuning parameters:
# hidden_dim: 128
# dropout: 0.6
# learning_rate: 0.0005
#
# max_len: 128
#
# embed_dim: 100
#
# CaptionRNN(
#   (embedding): Embedding(9991, 100, padding_idx=0)
#   (lstm): LSTM(100, 128, batch_first=True)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (fc_hidden): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
#   (fc_out): Linear(in_features=64, out_features=3, bias=True)
# )
#
# Epoch 1
# Train   | loss=1.1007, acc=0.352, macro-F1=0.180
# Test    | loss=1.0976, acc=0.311, macro-F1=0.166
# Train Confusion Matrix:
# [[  5   0 457]
#  [  4   0 492]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  2   0 145]
#  [  0   0 114]
#  [  0   0 115]]
#
# Epoch 2
# Train   | loss=1.1007, acc=0.363, macro-F1=0.204
# Test    | loss=1.0984, acc=0.309, macro-F1=0.161
# Train Confusion Matrix:
# [[ 18   1 443]
#  [  8   3 485]
#  [  0   0 513]]
# Test Confusion Matrix:
# [[  1   0 146]
#  [  0   0 114]
#  [  0   0 115]]
#
# Epoch 3
# Train   | loss=1.0983, acc=0.372, macro-F1=0.224
# Test    | loss=1.0986, acc=0.316, macro-F1=0.182
# Train Confusion Matrix:
# [[ 21   2 439]
#  [  7  15 474]
#  [  1   1 511]]
# Test Confusion Matrix:
# [[  6   0 141]
#  [  0   0 114]
#  [  2   0 113]]
#
# Epoch 4
# Train   | loss=1.0985, acc=0.387, macro-F1=0.256
# Test    | loss=1.0978, acc=0.314, macro-F1=0.186
# Train Confusion Matrix:
# [[ 34   3 425]
#  [  4  27 465]
#  [  4   1 508]]
# Test Confusion Matrix:
# [[  6   0 141]
#  [  2   1 111]
#  [  3   1 111]]
#
# Epoch 5
# Train   | loss=1.0963, acc=0.343, macro-F1=0.221
# Test    | loss=1.0978, acc=0.383, macro-F1=0.201
# Train Confusion Matrix:
# [[458   4   0]
#  [463  33   0]
#  [497   2  14]]
# Test Confusion Matrix:
# [[141   3   3]
#  [111   2   1]
#  [112   2   1]]
#
# Epoch 6
# Train   | loss=1.0961, acc=0.392, macro-F1=0.268
# Test    | loss=1.0985, acc=0.316, macro-F1=0.196
# Train Confusion Matrix:
# [[ 36   3 423]
#  [  0  34 462]
#  [  4   2 507]]
# Test Confusion Matrix:
# [[  7   3 137]
#  [  2   2 110]
#  [  3   2 110]]
#
# Epoch 7
# Train   | loss=1.0952, acc=0.392, macro-F1=0.265
# Test    | loss=1.0990, acc=0.316, macro-F1=0.196
# Train Confusion Matrix:
# [[ 33   6 423]
#  [  0  35 461]
#  [  3   2 508]]
# Test Confusion Matrix:
# [[  7   4 136]
#  [  2   2 110]
#  [  2   3 110]]
#
# Epoch 8
# Train   | loss=1.0917, acc=0.390, macro-F1=0.263
# Test    | loss=1.0994, acc=0.314, macro-F1=0.195
# Train Confusion Matrix:
# [[ 32   8 422]
#  [  0  35 461]
#  [  5   2 506]]
# Test Confusion Matrix:
# [[  7   4 136]
#  [  3   2 109]
#  [  3   3 109]]
#
# Epoch 9
# Train   | loss=1.0864, acc=0.391, macro-F1=0.264
# Test    | loss=1.1021, acc=0.314, macro-F1=0.192
# Train Confusion Matrix:
# [[ 32   7 423]
#  [  0  35 461]
#  [  5   0 508]]
# Test Confusion Matrix:
# [[  6   5 136]
#  [  3   2 109]
#  [  2   3 110]]
#
# Epoch 10
# Train   | loss=1.0784, acc=0.394, macro-F1=0.269
# Test    | loss=1.1028, acc=0.314, macro-F1=0.195
# Train Confusion Matrix:
# [[ 35   6 421]
#  [  0  36 460]
#  [  4   0 509]]
# Test Confusion Matrix:
# [[  7   5 135]
#  [  3   2 109]
#  [  3   3 109]]
# Early stopping at epoch 10

# %%
best_run = max(results, key=lambda x: x["test_macro_f1"])

plt.figure(figsize=(8,5))
plt.plot(best_run["train_f1_history"], label="Train Macro-F1")
plt.plot(best_run["test_f1_history"], label="Test Macro-F1")

plt.xlabel("Epoch")
plt.ylabel("Macro-F1")
plt.title(
    f"Best Run: hidden_dim={best_run['hidden_dim']}, "
    f"dropout={best_run['dropout']}, "
    f"learning_rate={best_run['learning_rate']}, "
    f"max_len={best_run['max_len']}, "
    f"embed_dim={best_run['embed_dim']}"
)
plt.legend()
plt.grid(True)
plt.show()

# %%
# Best model by test macro F1
best_row = df_results.loc[df_results["test_macro_f1"].idxmax()]
print(best_row)
# Out:
# model                                                            LSTM
# hidden_dim                                                        128
# dropout                                                           0.5
# learning_rate                                                  0.0005
# max_len                                                            64
# embed_dim                                                         100
# best_epoch                                                         20
# train_macro_f1                                               0.815337
# train_acc                                                    0.817811
# train_cm                 [[336, 98, 28], [35, 384, 77], [0, 30, 483]]
# test_macro_f1                                                0.515975
# test_acc                                                     0.518617
# test_cm                    [[76, 36, 35], [24, 53, 37], [20, 29, 66]]
# train_f1_history    [0.24716483634586495, 0.33874553297160226, 0.3...
# test_f1_history     [0.18378705082027205, 0.24870178358081585, 0.2...
# Name: 69, dtype: object

# %%
# Rank models by test macro F1
df_results.sort_values("test_macro_f1", ascending=False).head(5)
# Out:
#    model  hidden_dim  dropout  learning_rate  max_len  embed_dim  best_epoch  \
# 69  LSTM         128      0.5         0.0005       64        100          20
# 33  LSTM         128      0.5         0.0005       32        100          16
# 50  LSTM         128      0.5         0.0010       64         50          27
# 60  LSTM          64      0.3         0.0010       64        100          13
# 24  LSTM          64      0.3         0.0010       32        100          12
#
#     train_macro_f1  train_acc                                        train_cm  \
# 69        0.815337   0.817811    [[336, 98, 28], [35, 384, 77], [0, 30, 483]]
# 33        0.877374   0.875595      [[415, 8, 39], [8, 368, 120], [2, 6, 505]]
# 50        0.856699   0.858600      [[348, 86, 28], [6, 411, 79], [0, 9, 504]]
# 60        0.756819   0.760707  [[306, 116, 40], [31, 333, 132], [2, 31, 480]]
# 24        0.876995   0.878314     [[434, 7, 21], [28, 350, 118], [2, 3, 508]]
#
#     test_macro_f1  test_acc                                      test_cm  \
# 69       0.515975  0.518617   [[76, 36, 35], [24, 53, 37], [20, 29, 66]]
# 33       0.500988  0.518617  [[101, 25, 21], [44, 49, 21], [37, 33, 45]]
# 50       0.500475  0.507979   [[80, 46, 21], [25, 69, 20], [21, 52, 42]]
# 60       0.495944  0.497340   [[68, 50, 29], [18, 48, 48], [13, 31, 71]]
# 24       0.493297  0.492021   [[62, 57, 28], [26, 56, 32], [17, 31, 67]]
#
#                                      train_f1_history  \
# 69  [0.24716483634586495, 0.33874553297160226, 0.3...
# 33  [0.30029532030895045, 0.358044243338361, 0.398...
# 50  [0.30451784267786425, 0.3290584294558257, 0.34...
# 60  [0.18314042335197225, 0.3450180746261711, 0.34...
# 24  [0.37844203507645163, 0.4343878479910255, 0.46...
#
#                                       test_f1_history
# 69  [0.18378705082027205, 0.24870178358081585, 0.2...
# 33  [0.2591532498509243, 0.2965363244534455, 0.330...
# 50  [0.26077097505668934, 0.30622194427072474, 0.2...
# 60  [0.19159544159544162, 0.2883328730553254, 0.28...
# 24  [0.2860161917002763, 0.33228568971606004, 0.36...

# %%
# Compare hidden_dim effects
df_results.groupby("hidden_dim")["test_macro_f1"].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# hidden_dim
# 32           36.0  0.337703  0.098865  0.165707  0.215653  0.361259  0.424146
# 64           36.0  0.359700  0.107451  0.203451  0.229801  0.388211  0.454925
# 128          36.0  0.369527  0.118761  0.193770  0.222398  0.421996  0.470582
#
#                  max
# hidden_dim
# 32          0.462339
# 64          0.495944
# 128         0.515975

# %%
# Compare dropout effects
df_results.groupby("dropout")["test_macro_f1"].describe()
# Out:
#          count      mean       std       min       25%       50%       75%  \
# dropout
# 0.3       36.0  0.366572  0.109239  0.165707  0.239672  0.401099  0.463070
# 0.5       36.0  0.360443  0.114168  0.184520  0.229048  0.395094  0.451253
# 0.6       36.0  0.339915  0.102965  0.185149  0.211987  0.382061  0.427512
#
#               max
# dropout
# 0.3      0.495944
# 0.5      0.515975
# 0.6      0.465852

# %%
# Compare learning_rate effects
df_results.groupby("learning_rate")["test_macro_f1"].describe()
# Out:
#                count      mean       std       min       25%       50%  \
# learning_rate
# 0.0005          54.0  0.351954  0.112076  0.165707  0.219842  0.390729
# 0.0010          54.0  0.359333  0.105666  0.185895  0.233431  0.393511
#
#                     75%       max
# learning_rate
# 0.0005         0.441758  0.515975
# 0.0010         0.448107  0.500475

# %%
# Compare max_len effects
df_results.groupby("max_len")["test_macro_f1"].describe()
# Out:
#          count      mean       std       min       25%       50%       75%  \
# max_len
# 32        36.0  0.445586  0.033789  0.365107  0.431235  0.450181  0.465656
# 64        36.0  0.405908  0.053445  0.317087  0.358674  0.404450  0.431423
# 128       36.0  0.215436  0.028865  0.165707  0.199178  0.210941  0.223723
#
#               max
# max_len
# 32       0.500988
# 64       0.515975
# 128      0.322831

# %%
# Compare embed_dim effects
df_results.groupby("embed_dim")["test_macro_f1"].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# embed_dim
# 50          54.0  0.352783  0.106789  0.165707  0.223931  0.387688  0.441758
# 100         54.0  0.358504  0.111056  0.184520  0.221799  0.394513  0.450951
#
#                 max
# embed_dim
# 50         0.500475
# 100        0.515975

# %%
# Best epoch per configuration
df_results.loc[
    df_results.groupby(
        ["hidden_dim", "dropout", "learning_rate", "max_len", "embed_dim"]
    )["test_macro_f1"].idxmax()
]
# Out:
#     model  hidden_dim  dropout  learning_rate  max_len  embed_dim  best_epoch  \
# 1    LSTM          32      0.3         0.0005       32         50          11
# 19   LSTM          32      0.3         0.0005       32        100          14
# 37   LSTM          32      0.3         0.0005       64         50          13
# 55   LSTM          32      0.3         0.0005       64        100          16
# 73   LSTM          32      0.3         0.0005      128         50           2
# ..    ...         ...      ...            ...      ...        ...         ...
# 34   LSTM         128      0.6         0.0010       32        100           8
# 52   LSTM         128      0.6         0.0010       64         50          10
# 70   LSTM         128      0.6         0.0010       64        100          16
# 88   LSTM         128      0.6         0.0010      128         50           7
# 106  LSTM         128      0.6         0.0010      128        100           8
#
#      train_macro_f1  train_acc  \
# 1          0.621278   0.628824
# 19         0.612759   0.649898
# 37         0.521804   0.576479
# 55         0.538244   0.582597
# 73         0.192414   0.357580
# ..              ...        ...
# 34         0.808337   0.808294
# 52         0.548997   0.581917
# 70         0.654121   0.687967
# 88         0.261746   0.388171
# 106        0.277568   0.400408
#
#                                             train_cm  test_macro_f1  test_acc  \
# 1    [[305, 88, 69], [147, 227, 122], [65, 55, 393]]       0.455658  0.462766
# 19    [[435, 2, 25], [170, 128, 198], [92, 28, 393]]       0.397774  0.457447
# 37    [[318, 13, 131], [67, 59, 370], [25, 17, 471]]       0.423808  0.484043
# 55     [[296, 8, 158], [93, 88, 315], [23, 17, 473]]       0.400336  0.452128
# 73           [[5, 1, 456], [0, 9, 487], [0, 1, 512]]       0.165707  0.305851
# ..                                               ...            ...       ...
# 34      [[371, 65, 26], [58, 374, 64], [5, 64, 444]]       0.438064  0.438830
# 52   [[255, 68, 139], [83, 122, 291], [10, 24, 479]]       0.427419  0.449468
# 70      [[380, 18, 64], [49, 127, 320], [7, 1, 505]]       0.383371  0.425532
# 88         [[35, 3, 424], [3, 31, 462], [8, 0, 505]]       0.203378  0.319149
# 106        [[42, 0, 420], [0, 34, 462], [0, 0, 513]]       0.204524  0.321809
#
#                                         test_cm  \
# 1    [[64, 34, 49], [31, 39, 44], [24, 20, 71]]
# 19     [[89, 18, 40], [49, 8, 57], [31, 9, 75]]
# 37     [[93, 9, 45], [44, 11, 59], [33, 4, 78]]
# 55    [[73, 13, 61], [30, 11, 73], [23, 6, 86]]
# 73      [[1, 3, 143], [0, 1, 113], [0, 2, 113]]
# ..                                          ...
# 34   [[48, 59, 40], [23, 52, 39], [14, 36, 65]]
# 52   [[81, 33, 33], [45, 24, 45], [31, 20, 64]]
# 70    [[51, 17, 79], [15, 15, 84], [15, 6, 94]]
# 88      [[9, 4, 134], [2, 2, 110], [3, 3, 109]]
# 106     [[9, 3, 135], [4, 2, 108], [3, 2, 110]]
#
#                                       train_f1_history  \
# 1    [0.16911868836183927, 0.18532091854752927, 0.2...
# 19   [0.1749973760584248, 0.3414584176608721, 0.339...
# 37   [0.20227775690259367, 0.2757963003725716, 0.30...
# 55   [0.18318378384755804, 0.24128614236669246, 0.2...
# 73          [0.18129045311403724, 0.19241381268772587]
# ..                                                 ...
# 34   [0.3664167873470199, 0.3934866994625803, 0.473...
# 52   [0.3124865491433664, 0.32605714498093, 0.33660...
# 70   [0.318478663101101, 0.34025762406577414, 0.342...
# 88   [0.1942950905432462, 0.21556165841880126, 0.22...
# 106  [0.23790185959065868, 0.2504873718599867, 0.23...
#
#                                        test_f1_history
# 1    [0.15510204081632653, 0.1793716793716794, 0.23...
# 19   [0.20100586059270956, 0.31080550780503896, 0.2...
# 37   [0.17508646441020623, 0.24611314611314614, 0.2...
# 55   [0.17508646441020623, 0.20338556657072807, 0.2...
# 73          [0.16096708953851813, 0.16570744298017026]
# ..                                                 ...
# 34   [0.32706899688566876, 0.32972617561381606, 0.3...
# 52   [0.2826286901053256, 0.28058351306014856, 0.29...
# 70   [0.22838734941257566, 0.25708168026548894, 0.3...
# 88   [0.16487908219763195, 0.16862745098039214, 0.1...
# 106  [0.17201601655644036, 0.17296016907547843, 0.1...
#
# [108 rows x 15 columns]

# %% [markdown]
# # Clear memory

# %%
del model
torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 del model
#       2 torch.cuda.empty_cache()
#
# NameError: name 'model' is not defined
